# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy import stats
from scipy.stats import linregress

# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library
# ### To keep the same dataset that I created skip these commands until you come to the line that says to Begin Here...

# %%
# This code is provided
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 609

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Save config information
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# %%
# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}appid={weather_api_key}&q={city}&units={units}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | puerto natales
# Processing Record 2 of Set 1 | morehead city
# Processing Record 3 of Set 1 | adamstown
# Processing Record 4 of Set 1 | novonikolayevskiy
# Processing Record 5 of Set 1 | bargara
# City not found. Skipping...
# Processing Record 6 of Set 1 | hengchun
# Processing Record 7 of Set 1 | grytviken
# Processing Record 8 of Set 1 | glace bay
# Processing Record 9 of Set 1 | trincomalee
# Processing Record 10 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 11 of Set 1 | lagos
# Processing Record 12 of Set 1 | kirakira
# Processing Record 13 of Set 1 | waitangi
# Processing Record 14 of Set 1 | santa cruz
# Processing Record 15 of Set 1 | newman
# Processing Record 16 of Set 1 | lihue
# Processing Record 17 of Set 1 | lauro de freitas
# Processing Record 18 of Set 1 | infantes
# Processing Record 19 of Set 1 | polyarnyy
# Processing Record 20 of Set 1 | linqu
# Processing Record 21 of Set 1 | masumbwe
# Processing Record 22 of Set 1 | dudinka
# Processing Record 23 of Set 1 | saipan
# Processing Record 24 of Set 1 | bethel
# Processing Record 25 of Set 1 | baotou
# Processing Record 26 of Set 1 | atafu village
# Processing Record 27 of Set 1 | south lake tahoe
# Processing Record 28 of Set 1 | toga village
# City not found. Skipping...
# Processing Record 29 of Set 1 | thompson
# Processing Record 30 of Set 1 | palmer
# Processing Record 31 of Set 1 | iqaluit
# Processing Record 32 of Set 1 | blackmans bay
# Processing Record 33 of Set 1 | tazovsky
# Processing Record 34 of Set 1 | ushuaia
# Processing Record 35 of Set 1 | brasileia
# Processing Record 36 of Set 1 | papatowai
# Processing Record 37 of Set 1 | pemangkat
# Processing Record 38 of Set 1 | vadso
# Processing Record 39 of Set 1 | kodiak
# Processing Record 40 of Set 1 | gonabad
# Processing Record 41 of Set 1 | ahau
# City not found. Skipping...
# Processing Record 42 of Set 1 | le lavandou
# Processing Record 43 of Set 1 | olonkinbyen
# Processing Record 44 of Set 1 | ust'-ilimsk
# Processing Record 45 of Set 1 | kerikeri
# Processing Record 46 of Set 1 | hasaki
# Processing Record 47 of Set 1 | miyanoura
# City not found. Skipping...
# Processing Record 48 of Set 1 | keflavik
# Processing Record 49 of Set 1 | edinburgh of the seven seas
# Processing Record 50 of Set 1 | fortaleza
# Processing Record 0 of Set 2 | hithadhoo
# Processing Record 1 of Set 2 | taroa
# Processing Record 2 of Set 2 | isafjordur
# Processing Record 3 of Set 2 | port-aux-francais
# Processing Record 4 of Set 2 | ancud
# Processing Record 5 of Set 2 | nova xavantina
# Processing Record 6 of Set 2 | chake chake
# Processing Record 7 of Set 2 | toliara
# Processing Record 8 of Set 2 | timbuktu
# Processing Record 9 of Set 2 | port mathurin
# Processing Record 10 of Set 2 | kokkola
# Processing Record 11 of Set 2 | suomussalmi
# Processing Record 12 of Set 2 | college
# Processing Record 13 of Set 2 | dhidhdhoo
# Processing Record 14 of Set 2 | carnarvon
# Processing Record 15 of Set 2 | bay roberts
# Processing Record 16 of Set 2 | nizhnesortymskiy
# Processing Record 17 of Set 2 | puerto aysen
# Processing Record 18 of Set 2 | edmundston
# Processing Record 19 of Set 2 | klyuchi
# Processing Record 20 of Set 2 | akureyri
# Processing Record 21 of Set 2 | yellowknife
# Processing Record 22 of Set 2 | barranca
# Processing Record 23 of Set 2 | albany
# Processing Record 24 of Set 2 | hawaiian paradise park
# Processing Record 25 of Set 2 | greenland
# Processing Record 26 of Set 2 | ulladulla
# Processing Record 27 of Set 2 | port saint john's
# Processing Record 28 of Set 2 | castillos
# Processing Record 29 of Set 2 | dauphin
# Processing Record 30 of Set 2 | alice springs
# Processing Record 31 of Set 2 | mount hawthorn
# Processing Record 32 of Set 2 | margaret river
# Processing Record 33 of Set 2 | pubal
# Processing Record 34 of Set 2 | ribeira grande
# Processing Record 35 of Set 2 | codrington
# Processing Record 36 of Set 2 | pacific grove
# Processing Record 37 of Set 2 | arica
# Processing Record 38 of Set 2 | chimbarongo
# Processing Record 39 of Set 2 | la mira
# Processing Record 40 of Set 2 | sake
# Processing Record 41 of Set 2 | arraial do cabo
# Processing Record 42 of Set 2 | sylt-ost
# Processing Record 43 of Set 2 | beohari
# Processing Record 44 of Set 2 | shakawe
# Processing Record 45 of Set 2 | hermanus
# Processing Record 46 of Set 2 | kadi
# Processing Record 47 of Set 2 | vila velha
# Processing Record 48 of Set 2 | pukchil-lodongjagu
# Processing Record 49 of Set 2 | togur
# Processing Record 0 of Set 3 | labrador city
# Processing Record 1 of Set 3 | susuman
# Processing Record 2 of Set 3 | port lincoln
# Processing Record 3 of Set 3 | sos'va
# Processing Record 4 of Set 3 | motueka
# Processing Record 5 of Set 3 | monte santo
# Processing Record 6 of Set 3 | invercargill
# Processing Record 7 of Set 3 | kapa'a
# Processing Record 8 of Set 3 | tual
# Processing Record 9 of Set 3 | whitehorse
# Processing Record 10 of Set 3 | talnakh
# Processing Record 11 of Set 3 | bredasdorp
# Processing Record 12 of Set 3 | chelghoum el aid
# Processing Record 13 of Set 3 | anadyr
# Processing Record 14 of Set 3 | siparia
# Processing Record 15 of Set 3 | chibougamau
# Processing Record 16 of Set 3 | zheleznogorsk-ilimskiy
# Processing Record 17 of Set 3 | atasu
# Processing Record 18 of Set 3 | lazaro cardenas
# Processing Record 19 of Set 3 | avarua
# Processing Record 20 of Set 3 | afaahiti
# Processing Record 21 of Set 3 | ulanhot
# Processing Record 22 of Set 3 | bera
# Processing Record 23 of Set 3 | jijel
# Processing Record 24 of Set 3 | west island
# Processing Record 25 of Set 3 | flying fish cove
# Processing Record 26 of Set 3 | lae
# Processing Record 27 of Set 3 | puerto baquerizo moreno
# Processing Record 28 of Set 3 | pindiga
# Processing Record 29 of Set 3 | champoton
# Processing Record 30 of Set 3 | bataipora
# Processing Record 31 of Set 3 | tura
# Processing Record 32 of Set 3 | sisimiut
# Processing Record 33 of Set 3 | qaqortoq
# Processing Record 34 of Set 3 | kabalo
# Processing Record 35 of Set 3 | badger
# Processing Record 36 of Set 3 | shangri-la
# City not found. Skipping...
# Processing Record 37 of Set 3 | cova figueira
# Processing Record 38 of Set 3 | georgetown
# Processing Record 39 of Set 3 | puerto ayora
# Processing Record 40 of Set 3 | igarka
# Processing Record 41 of Set 3 | wailua homesteads
# Processing Record 42 of Set 3 | camana
# Processing Record 43 of Set 3 | fenoarivo atsinanana
# Processing Record 44 of Set 3 | nar'yan-mar
# Processing Record 45 of Set 3 | masterton
# Processing Record 46 of Set 3 | kailua-kona
# Processing Record 47 of Set 3 | east london
# Processing Record 48 of Set 3 | dompu
# Processing Record 49 of Set 3 | fisterra
# Processing Record 0 of Set 4 | hamilton
# Processing Record 1 of Set 4 | bamyan
# Processing Record 2 of Set 4 | lerwick
# Processing Record 3 of Set 4 | la maddalena
# Processing Record 4 of Set 4 | lompoc
# Processing Record 5 of Set 4 | dapa
# Processing Record 6 of Set 4 | minas de marcona
# Processing Record 7 of Set 4 | bilibino
# Processing Record 8 of Set 4 | goundam
# Processing Record 9 of Set 4 | taltal
# Processing Record 10 of Set 4 | okhotsk
# Processing Record 11 of Set 4 | isangel
# Processing Record 12 of Set 4 | aginskoye
# Processing Record 13 of Set 4 | murtosa
# Processing Record 14 of Set 4 | marsaskala
# City not found. Skipping...
# Processing Record 15 of Set 4 | waddan
# Processing Record 16 of Set 4 | raseiniai
# Processing Record 17 of Set 4 | punta arenas
# Processing Record 18 of Set 4 | 'ohonua
# City not found. Skipping...
# Processing Record 19 of Set 4 | rawson
# Processing Record 20 of Set 4 | raduzhnyy
# Processing Record 21 of Set 4 | luderitz
# Processing Record 22 of Set 4 | horta
# Processing Record 23 of Set 4 | rosso
# Processing Record 24 of Set 4 | moses lake
# Processing Record 25 of Set 4 | geraldton
# Processing Record 26 of Set 4 | puerto san carlos
# City not found. Skipping...
# Processing Record 27 of Set 4 | fonte boa
# Processing Record 28 of Set 4 | mendi
# Processing Record 29 of Set 4 | ippy
# Processing Record 30 of Set 4 | pitimbu
# Processing Record 31 of Set 4 | inhambane
# Processing Record 32 of Set 4 | xilin hot
# Processing Record 33 of Set 4 | hami
# Processing Record 34 of Set 4 | crane
# Processing Record 35 of Set 4 | cadale
# Processing Record 36 of Set 4 | saudarkrokur
# Processing Record 37 of Set 4 | uturoa
# Processing Record 38 of Set 4 | jamestown
# Processing Record 39 of Set 4 | sao jose da coroa grande
# Processing Record 40 of Set 4 | new norfolk
# Processing Record 41 of Set 4 | gariaband
# Processing Record 42 of Set 4 | xindi
# Processing Record 43 of Set 4 | mount isa
# Processing Record 44 of Set 4 | mejit
# Processing Record 45 of Set 4 | porto franco
# Processing Record 46 of Set 4 | remire-montjoly
# Processing Record 47 of Set 4 | longyearbyen
# Processing Record 48 of Set 4 | holualoa
# Processing Record 49 of Set 4 | rio grande
# Processing Record 0 of Set 5 | chonchi
# Processing Record 1 of Set 5 | imbert
# Processing Record 2 of Set 5 | brisas de zicatela
# Processing Record 3 of Set 5 | egilsstadir
# Processing Record 4 of Set 5 | nili
# Processing Record 5 of Set 5 | basoko
# Processing Record 6 of Set 5 | black point
# Processing Record 7 of Set 5 | bride
# Processing Record 8 of Set 5 | kununurra
# Processing Record 9 of Set 5 | duncan town
# City not found. Skipping...
# Processing Record 10 of Set 5 | udachny
# Processing Record 11 of Set 5 | ilulissat
# Processing Record 12 of Set 5 | wagar
# Processing Record 13 of Set 5 | colonia
# Processing Record 14 of Set 5 | contai
# Processing Record 15 of Set 5 | itoman
# Processing Record 16 of Set 5 | en naqoura
# City not found. Skipping...
# Processing Record 17 of Set 5 | turbat
# Processing Record 18 of Set 5 | oban
# Processing Record 19 of Set 5 | muscat
# Processing Record 20 of Set 5 | es castell
# Processing Record 21 of Set 5 | stanley
# Processing Record 22 of Set 5 | tobi village
# City not found. Skipping...
# Processing Record 23 of Set 5 | port elizabeth
# Processing Record 24 of Set 5 | hirara
# Processing Record 25 of Set 5 | aasiaat
# Processing Record 26 of Set 5 | pelabuhanratu
# Processing Record 27 of Set 5 | montanha
# Processing Record 28 of Set 5 | caleta olivia
# Processing Record 29 of Set 5 | grand-lahou
# Processing Record 30 of Set 5 | kimberley
# Processing Record 31 of Set 5 | pisco
# Processing Record 32 of Set 5 | kamina
# Processing Record 33 of Set 5 | prince edward
# Processing Record 34 of Set 5 | khandyga
# Processing Record 35 of Set 5 | yanam
# Processing Record 36 of Set 5 | laredo
# Processing Record 37 of Set 5 | acapulco de juarez
# Processing Record 38 of Set 5 | sandakan
# Processing Record 39 of Set 5 | lebu
# Processing Record 40 of Set 5 | tiksi
# Processing Record 41 of Set 5 | constantia
# Processing Record 42 of Set 5 | ola
# Processing Record 43 of Set 5 | duba
# Processing Record 44 of Set 5 | san antonio de pale
# Processing Record 45 of Set 5 | christchurch
# Processing Record 46 of Set 5 | francistown
# Processing Record 47 of Set 5 | huocheng
# City not found. Skipping...
# Processing Record 48 of Set 5 | gemena
# Processing Record 49 of Set 5 | san cristobal
# Processing Record 0 of Set 6 | kenai
# Processing Record 1 of Set 6 | west valley
# Processing Record 2 of Set 6 | petropavlovsk-kamchatsky
# Processing Record 3 of Set 6 | katsuura
# Processing Record 4 of Set 6 | petropavlovka
# Processing Record 5 of Set 6 | taunggyi
# Processing Record 6 of Set 6 | al ghayzah
# Processing Record 7 of Set 6 | la'ie
# Processing Record 8 of Set 6 | khobar
# Processing Record 9 of Set 6 | nemuro
# Processing Record 10 of Set 6 | howard springs
# Processing Record 11 of Set 6 | griffith
# Processing Record 12 of Set 6 | goure
# Processing Record 13 of Set 6 | omuthiya
# City not found. Skipping...
# Processing Record 14 of Set 6 | enewetak
# Processing Record 15 of Set 6 | sao joao da barra
# Processing Record 16 of Set 6 | marat
# Processing Record 17 of Set 6 | walvis bay
# Processing Record 18 of Set 6 | stornoway
# Processing Record 19 of Set 6 | mocorito
# Processing Record 20 of Set 6 | minbu
# Processing Record 21 of Set 6 | yerofey pavlovich
# Processing Record 22 of Set 6 | khorugh
# Processing Record 23 of Set 6 | sitka
# Processing Record 24 of Set 6 | nova sintra
# Processing Record 25 of Set 6 | copala
# Processing Record 26 of Set 6 | sabang
# Processing Record 27 of Set 6 | antofagasta
# Processing Record 28 of Set 6 | gaspe
# Processing Record 29 of Set 6 | ciudad lazaro cardenas
# Processing Record 30 of Set 6 | kimbe
# Processing Record 31 of Set 6 | kalaleh
# Processing Record 32 of Set 6 | port alfred
# Processing Record 33 of Set 6 | el calafate
# Processing Record 34 of Set 6 | takoradi
# Processing Record 35 of Set 6 | belyy yar
# Processing Record 36 of Set 6 | cromwell
# Processing Record 37 of Set 6 | caconda
# Processing Record 38 of Set 6 | vingt cinq
# City not found. Skipping...
# Processing Record 39 of Set 6 | tocache
# Processing Record 40 of Set 6 | weno
# Processing Record 41 of Set 6 | lagoa
# Processing Record 42 of Set 6 | east falmouth
# Processing Record 43 of Set 6 | konakovo
# Processing Record 44 of Set 6 | colares
# Processing Record 45 of Set 6 | la ronge
# Processing Record 46 of Set 6 | alofi
# Processing Record 47 of Set 6 | broome
# Processing Record 48 of Set 6 | namsos
# Processing Record 49 of Set 6 | maceio
# Processing Record 0 of Set 7 | sokhumi
# Processing Record 1 of Set 7 | nahiyat ash shinafiyah
# Processing Record 2 of Set 7 | tangalle
# Processing Record 3 of Set 7 | kulim
# Processing Record 4 of Set 7 | pyhajarvi
# Processing Record 5 of Set 7 | karak city
# Processing Record 6 of Set 7 | brookings
# Processing Record 7 of Set 7 | castries
# Processing Record 8 of Set 7 | marotta
# Processing Record 9 of Set 7 | kuta
# Processing Record 10 of Set 7 | papao
# Processing Record 11 of Set 7 | kulunda
# Processing Record 12 of Set 7 | byron bay
# Processing Record 13 of Set 7 | alotau
# Processing Record 14 of Set 7 | hailar
# Processing Record 15 of Set 7 | ust-nera
# Processing Record 16 of Set 7 | lhokseumawe
# Processing Record 17 of Set 7 | am djarass
# City not found. Skipping...
# Processing Record 18 of Set 7 | sinabang
# Processing Record 19 of Set 7 | fale old settlement
# Processing Record 20 of Set 7 | misliyah
# Processing Record 21 of Set 7 | kegeyli shahar
# Processing Record 22 of Set 7 | nogales
# Processing Record 23 of Set 7 | cockburn town
# Processing Record 24 of Set 7 | lubango
# Processing Record 25 of Set 7 | manuel ojinaga
# City not found. Skipping...
# Processing Record 26 of Set 7 | saint-francois
# Processing Record 27 of Set 7 | lorengau
# Processing Record 28 of Set 7 | nykarleby
# Processing Record 29 of Set 7 | naze
# Processing Record 30 of Set 7 | sanya
# Processing Record 31 of Set 7 | pizarro
# Processing Record 32 of Set 7 | viqueque
# Processing Record 33 of Set 7 | embarcacion
# Processing Record 34 of Set 7 | kashgar
# Processing Record 35 of Set 7 | fortuna
# Processing Record 36 of Set 7 | hafnarfjordur
# Processing Record 37 of Set 7 | bath
# Processing Record 38 of Set 7 | nouadhibou
# Processing Record 39 of Set 7 | vila franca do campo
# Processing Record 40 of Set 7 | vilyuchinsk
# Processing Record 41 of Set 7 | qarazhal
# Processing Record 42 of Set 7 | porto tolle
# Processing Record 43 of Set 7 | santa maria do para
# Processing Record 44 of Set 7 | sandpoint
# Processing Record 45 of Set 7 | salyan
# Processing Record 46 of Set 7 | kavaratti
# Processing Record 47 of Set 7 | luang prabang
# Processing Record 48 of Set 7 | mount pearl
# Processing Record 49 of Set 7 | flin flon
# Processing Record 0 of Set 8 | vorkuta
# Processing Record 1 of Set 8 | malango
# Processing Record 2 of Set 8 | utrik
# Processing Record 3 of Set 8 | el haouaria
# Processing Record 4 of Set 8 | kelowna
# Processing Record 5 of Set 8 | fort st. john
# Processing Record 6 of Set 8 | laguna
# Processing Record 7 of Set 8 | port moresby
# Processing Record 8 of Set 8 | pineville
# Processing Record 9 of Set 8 | elmendorf air force base
# City not found. Skipping...
# Processing Record 10 of Set 8 | tolanaro
# Processing Record 11 of Set 8 | sumbe
# Processing Record 12 of Set 8 | fort bragg
# Processing Record 13 of Set 8 | tsiombe
# Processing Record 14 of Set 8 | sao vicente
# Processing Record 15 of Set 8 | shihezi
# Processing Record 16 of Set 8 | grand falls-windsor
# Processing Record 17 of Set 8 | borgonovo valtidone
# Processing Record 18 of Set 8 | sittwe
# Processing Record 19 of Set 8 | paracuru
# Processing Record 20 of Set 8 | beaconsfield
# Processing Record 21 of Set 8 | la passe
# Processing Record 22 of Set 8 | peace river
# Processing Record 23 of Set 8 | sisak
# Processing Record 24 of Set 8 | sinjai
# Processing Record 25 of Set 8 | kalmunai
# Processing Record 26 of Set 8 | illizi
# Processing Record 27 of Set 8 | gadzhiyevo
# Processing Record 28 of Set 8 | tamanrasset
# Processing Record 29 of Set 8 | kharp
# Processing Record 30 of Set 8 | st. john's
# Processing Record 31 of Set 8 | letlhakane
# Processing Record 32 of Set 8 | nyurba
# Processing Record 33 of Set 8 | lubao
# Processing Record 34 of Set 8 | ambodifotatra
# Processing Record 35 of Set 8 | duong dong
# Processing Record 36 of Set 8 | mandvi
# Processing Record 37 of Set 8 | zag
# Processing Record 38 of Set 8 | curillo
# Processing Record 39 of Set 8 | bikenibeu village
# Processing Record 40 of Set 8 | xinyang
# Processing Record 41 of Set 8 | lobito
# Processing Record 42 of Set 8 | bovalino
# Processing Record 43 of Set 8 | margate
# Processing Record 44 of Set 8 | wundanyi
# Processing Record 45 of Set 8 | opuwo
# Processing Record 46 of Set 8 | voznesensk
# Processing Record 47 of Set 8 | nukunonu
# City not found. Skipping...
# Processing Record 48 of Set 8 | cargados carajos
# City not found. Skipping...
# Processing Record 49 of Set 8 | ergani
# Processing Record 0 of Set 9 | belel
# Processing Record 1 of Set 9 | selfoss
# Processing Record 2 of Set 9 | namdrik
# Processing Record 3 of Set 9 | yarmouth
# Processing Record 4 of Set 9 | adrar
# Processing Record 5 of Set 9 | ouadda
# Processing Record 6 of Set 9 | praia da vitoria
# Processing Record 7 of Set 9 | jiuquan
# Processing Record 8 of Set 9 | yorkton
# Processing Record 9 of Set 9 | iskateley
# Processing Record 10 of Set 9 | corner brook
# Processing Record 11 of Set 9 | san nicolas
# Processing Record 12 of Set 9 | samraong
# Processing Record 13 of Set 9 | vorgashor
# Processing Record 14 of Set 9 | port glaud
# City not found. Skipping...
# Processing Record 15 of Set 9 | tommot
# Processing Record 16 of Set 9 | cantagalo
# Processing Record 17 of Set 9 | akrehamn
# Processing Record 18 of Set 9 | tralee
# Processing Record 19 of Set 9 | kingston
# Processing Record 20 of Set 9 | mbandaka
# Processing Record 21 of Set 9 | guiuan
# Processing Record 22 of Set 9 | namibe
# Processing Record 23 of Set 9 | yigo village
# Processing Record 24 of Set 9 | estevan
# Processing Record 25 of Set 9 | hampton bays
# Processing Record 26 of Set 9 | najaf
# Processing Record 27 of Set 9 | kuqa
# Processing Record 28 of Set 9 | plettenberg bay
# Processing Record 29 of Set 9 | nova vicosa
# Processing Record 30 of Set 9 | pandan
# Processing Record 31 of Set 9 | hammerfest
# Processing Record 32 of Set 9 | andkhoy
# Processing Record 33 of Set 9 | zuunmod
# Processing Record 34 of Set 9 | bonthe
# Processing Record 35 of Set 9 | woodlake
# Processing Record 36 of Set 9 | templin
# Processing Record 37 of Set 9 | zvishavane
# Processing Record 38 of Set 9 | kataragama
# City not found. Skipping...
# Processing Record 39 of Set 9 | bubaque
# Processing Record 40 of Set 9 | sebezh
# Processing Record 41 of Set 9 | tromso
# Processing Record 42 of Set 9 | mitsamiouli
# Processing Record 43 of Set 9 | nuuk
# Processing Record 44 of Set 9 | pyt-yakh
# Processing Record 45 of Set 9 | paso de carrasco
# Processing Record 46 of Set 9 | argo
# Processing Record 47 of Set 9 | mutoko
# Processing Record 48 of Set 9 | guangyuan
# Processing Record 49 of Set 9 | sur
# Processing Record 0 of Set 10 | pallasovka
# Processing Record 1 of Set 10 | sipalay
# Processing Record 2 of Set 10 | jose maria morelos
# Processing Record 3 of Set 10 | tocopilla
# Processing Record 4 of Set 10 | fuvahmulah
# City not found. Skipping...
# Processing Record 5 of Set 10 | pontarlier
# Processing Record 6 of Set 10 | ilha de mocambique
# Processing Record 7 of Set 10 | ushtobe
# Processing Record 8 of Set 10 | necochea
# Processing Record 9 of Set 10 | manta
# Processing Record 10 of Set 10 | san pedro de macoris
# Processing Record 11 of Set 10 | bardai
# Processing Record 12 of Set 10 | vernal
# Processing Record 13 of Set 10 | atakpame
# Processing Record 14 of Set 10 | kaa-khem
# Processing Record 15 of Set 10 | steamboat springs
# Processing Record 16 of Set 10 | bogale
# Processing Record 17 of Set 10 | pathein
# Processing Record 18 of Set 10 | severo-yeniseyskiy
# Processing Record 19 of Set 10 | tuba city
# Processing Record 20 of Set 10 | nieuw nickerie
# Processing Record 21 of Set 10 | chimore
# Processing Record 22 of Set 10 | oroqen zizhiqi
# Processing Record 23 of Set 10 | banda aceh
# Processing Record 24 of Set 10 | teknaf
# Processing Record 25 of Set 10 | cabo san lucas
# Processing Record 26 of Set 10 | pauini
# Processing Record 27 of Set 10 | mount pleasant
# Processing Record 28 of Set 10 | iwaki
# Processing Record 29 of Set 10 | cumana
# Processing Record 30 of Set 10 | aquin
# Processing Record 31 of Set 10 | coahuayana de hidalgo
# Processing Record 32 of Set 10 | aykhal
# Processing Record 33 of Set 10 | cannonvale
# Processing Record 34 of Set 10 | keelung
# Processing Record 35 of Set 10 | patterson
# Processing Record 36 of Set 10 | amqui
# Processing Record 37 of Set 10 | jinhua
# Processing Record 38 of Set 10 | macapa
# Processing Record 39 of Set 10 | san fernando
# Processing Record 40 of Set 10 | lashio
# Processing Record 41 of Set 10 | buncrana
# Processing Record 42 of Set 10 | caxito
# Processing Record 43 of Set 10 | javanrud
# Processing Record 44 of Set 10 | coquimbo
# Processing Record 45 of Set 10 | north manchester
# Processing Record 46 of Set 10 | aripuana
# Processing Record 47 of Set 10 | port sudan
# Processing Record 48 of Set 10 | antsiranana
# Processing Record 49 of Set 10 | karkira
# Processing Record 0 of Set 11 | conduaga
# Processing Record 1 of Set 11 | salinas
# Processing Record 2 of Set 11 | san jose del guaviare
# Processing Record 3 of Set 11 | kaya
# Processing Record 4 of Set 11 | umm kaddadah
# Processing Record 5 of Set 11 | hobyo
# Processing Record 6 of Set 11 | melouza
# Processing Record 7 of Set 11 | male
# Processing Record 8 of Set 11 | serdar
# Processing Record 9 of Set 11 | singojuruh
# Processing Record 10 of Set 11 | thinadhoo
# Processing Record 11 of Set 11 | al kharijah
# Processing Record 12 of Set 11 | kargopol'
# Processing Record 13 of Set 11 | tevragh zeina
# City not found. Skipping...
# Processing Record 14 of Set 11 | guajara mirim
# Processing Record 15 of Set 11 | villa la angostura
# Processing Record 16 of Set 11 | madalena
# Processing Record 17 of Set 11 | gusev
# Processing Record 18 of Set 11 | morinville
# Processing Record 19 of Set 11 | turabah
# Processing Record 20 of Set 11 | ponta delgada
# Processing Record 21 of Set 11 | paita
# Processing Record 22 of Set 11 | guelendeng
# Processing Record 23 of Set 11 | deir ez-zor
# Processing Record 24 of Set 11 | san matias
# Processing Record 25 of Set 11 | yaren
# Processing Record 26 of Set 11 | airdrie
# Processing Record 27 of Set 11 | salinopolis
# Processing Record 28 of Set 11 | ribeira brava
# Processing Record 29 of Set 11 | san pedro pochutla
# Processing Record 30 of Set 11 | kijang
# Processing Record 31 of Set 11 | priozersk
# Processing Record 32 of Set 11 | agapovka
# Processing Record 33 of Set 11 | el matama
# Processing Record 34 of Set 11 | stephenville
# Processing Record 35 of Set 11 | kavieng
# Processing Record 36 of Set 11 | north battleford
# Processing Record 37 of Set 11 | ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 38 of Set 11 | manadhoo
# Processing Record 39 of Set 11 | inverloch
# Processing Record 40 of Set 11 | hadibu
# Processing Record 41 of Set 11 | san andres
# Processing Record 42 of Set 11 | kanker
# Processing Record 43 of Set 11 | broken hill
# Processing Record 44 of Set 11 | kemijarvi
# Processing Record 45 of Set 11 | stassfurt
# Processing Record 46 of Set 11 | sofifi
# Processing Record 47 of Set 11 | shimoda
# Processing Record 48 of Set 11 | fort mcmurray
# Processing Record 49 of Set 11 | nagato
# Processing Record 0 of Set 12 | kundla
# Processing Record 1 of Set 12 | bandar-e lengeh
# Processing Record 2 of Set 12 | tranovaho
# City not found. Skipping...
# Processing Record 3 of Set 12 | naranjal
# Processing Record 4 of Set 12 | bonny
# Processing Record 5 of Set 12 | satupa'itea
# City not found. Skipping...
# Processing Record 6 of Set 12 | portland
# Processing Record 7 of Set 12 | fougamou
# Processing Record 8 of Set 12 | bamboo flat
# Processing Record 9 of Set 12 | mumbwa
# Processing Record 10 of Set 12 | uyskoye
# Processing Record 11 of Set 12 | tazacorte
# Processing Record 12 of Set 12 | altai
# Processing Record 13 of Set 12 | camacupa
# Processing Record 14 of Set 12 | malvan
# Processing Record 15 of Set 12 | labytnangi
# Processing Record 16 of Set 12 | onguday
# Processing Record 17 of Set 12 | kolwezi
# Processing Record 18 of Set 12 | mukah
# City not found. Skipping...
# Processing Record 19 of Set 12 | paphos
# Processing Record 20 of Set 12 | piacabucu
# Processing Record 21 of Set 12 | kani keli
# Processing Record 22 of Set 12 | fukuecho
# Processing Record 23 of Set 12 | ardabil
# Processing Record 24 of Set 12 | cidreira
# Processing Record 25 of Set 12 | aioun
# Processing Record 26 of Set 12 | gulf shores
# Processing Record 27 of Set 12 | guskhara
# Processing Record 28 of Set 12 | kouroussa
# Processing Record 29 of Set 12 | olyokminsk
# Processing Record 30 of Set 12 | koungou
# Processing Record 31 of Set 12 | al bawiti
# Processing Record 32 of Set 12 | dalandzadgad
# Processing Record 33 of Set 12 | aksu
# Processing Record 34 of Set 12 | vernon
# Processing Record 35 of Set 12 | roma
# Processing Record 36 of Set 12 | aviles
# Processing Record 37 of Set 12 | dolzhanskaya
# Processing Record 38 of Set 12 | niafunke
# Processing Record 39 of Set 12 | yagry
# City not found. Skipping...
# Processing Record 40 of Set 12 | vershino-darasunskiy
# Processing Record 41 of Set 12 | kapuskasing
# Processing Record 42 of Set 12 | winslow
# Processing Record 43 of Set 12 | shaowu
# Processing Record 44 of Set 12 | nagqu
# Processing Record 45 of Set 12 | ordynskoye
# Processing Record 46 of Set 12 | shalkar
# Processing Record 47 of Set 12 | cafayate
# Processing Record 48 of Set 12 | karratha
# Processing Record 49 of Set 12 | kirensk
# Processing Record 0 of Set 13 | kanniyakumari
# Processing Record 1 of Set 13 | anabar
# City not found. Skipping...
# Processing Record 2 of Set 13 | n'zeto
# Processing Record 3 of Set 13 | mount gambier
# Processing Record 4 of Set 13 | tayoltita
# Processing Record 5 of Set 13 | haiku-pauwela
# Processing Record 6 of Set 13 | muang phon-hong
# Processing Record 7 of Set 13 | ciudad guadalupe victoria
# Processing Record 8 of Set 13 | kikwit
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data
# Out:
# [{'City': 'puerto natales',
#   'Lat': -51.7236,
#   'Lng': -72.4875,
#   'Max Temp': 3.38,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 2.68,
#   'Country': 'CL',
#   'Date': 1725675954},
#  {'City': 'morehead city',
#   'Lat': 34.7229,
#   'Lng': -76.726,
#   'Max Temp': 24.44,
#   'Humidity': 86,
#   'Cloudiness': 0,
#   'Wind Speed': 2.24,
#   'Country': 'US',
#   'Date': 1725675954},
#  {'City': 'adamstown',
#   'Lat': -25.066,
#   'Lng': -130.1015,
#   'Max Temp': 18.33,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 10.32,
#   'Country': 'PN',
#   'Date': 1725675954},
#  {'City': 'novonikolayevskiy',
#   'Lat': 50.9738,
#   'Lng': 42.3649,
#   'Max Temp': 10.67,
#   'Humidity': 53,
#   'Cloudiness': 0,
#   'Wind Speed': 1.75,
#   'Country': 'RU',
#   'Date': 1725675954},
#  {'City': 'hengchun',
#   'Lat': 22.0042,
#   'Lng': 120.7439,
#   'Max Temp': 27.35,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 4.52,
#   'Country': 'TW',
#   'Date': 1725675955},
#  {'City': 'grytviken',
#   'Lat': -54.2811,
#   'Lng': -36.5092,
#   'Max Temp': 1.09,
#   'Humidity': 91,
#   'Cloudiness': 98,
#   'Wind Speed': 1.15,
#   'Country': 'GS',
#   'Date': 1725675955},
#  {'City': 'glace bay',
#   'Lat': 46.1969,
#   'Lng': -59.957,
#   'Max Temp': 17.16,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 1.34,
#   'Country': 'CA',
#   'Date': 1725675852},
#  {'City': 'trincomalee',
#   'Lat': 8.5711,
#   'Lng': 81.2335,
#   'Max Temp': 27.99,
#   'Humidity': 75,
#   'Cloudiness': 99,
#   'Wind Speed': 9.91,
#   'Country': 'LK',
#   'Date': 1725675955},
#  {'City': 'lagos',
#   'Lat': 6.5833,
#   'Lng': 3.75,
#   'Max Temp': 23.7,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 1.25,
#   'Country': 'NG',
#   'Date': 1725675604},
#  {'City': 'kirakira',
#   'Lat': -10.4544,
#   'Lng': 161.9205,
#   'Max Temp': 27.1,
#   'Humidity': 66,
#   'Cloudiness': 100,
#   'Wind Speed': 8.07,
#   'Country': 'SB',
#   'Date': 1725675955},
#  {'City': 'waitangi',
#   'Lat': -43.9535,
#   'Lng': -176.5597,
#   'Max Temp': 12.12,
#   'Humidity': 84,
#   'Cloudiness': 86,
#   'Wind Speed': 3.58,
#   'Country': 'NZ',
#   'Date': 1725675955},
#  {'City': 'santa cruz',
#   'Lat': -17.8,
#   'Lng': -63.1667,
#   'Max Temp': 22.7,
#   'Humidity': 56,
#   'Cloudiness': 0,
#   'Wind Speed': 4.63,
#   'Country': 'BO',
#   'Date': 1725675693},
#  {'City': 'newman',
#   'Lat': 37.3138,
#   'Lng': -121.0208,
#   'Max Temp': 33.91,
#   'Humidity': 28,
#   'Cloudiness': 0,
#   'Wind Speed': 2.68,
#   'Country': 'US',
#   'Date': 1725675955},
#  {'City': 'lihue',
#   'Lat': 21.9789,
#   'Lng': -159.3672,
#   'Max Temp': 28.77,
#   'Humidity': 63,
#   'Cloudiness': 0,
#   'Wind Speed': 5.14,
#   'Country': 'US',
#   'Date': 1725675956},
#  {'City': 'lauro de freitas',
#   'Lat': -12.8944,
#   'Lng': -38.3272,
#   'Max Temp': 24.01,
#   'Humidity': 78,
#   'Cloudiness': 40,
#   'Wind Speed': 4.12,
#   'Country': 'BR',
#   'Date': 1725675809},
#  {'City': 'infantes',
#   'Lat': 38.7367,
#   'Lng': -3.0122,
#   'Max Temp': 16.91,
#   'Humidity': 36,
#   'Cloudiness': 0,
#   'Wind Speed': 3.22,
#   'Country': 'ES',
#   'Date': 1725675956},
#  {'City': 'polyarnyy',
#   'Lat': 69.1989,
#   'Lng': 33.4478,
#   'Max Temp': 10.72,
#   'Humidity': 87,
#   'Cloudiness': 2,
#   'Wind Speed': 3.2,
#   'Country': 'RU',
#   'Date': 1725675956},
#  {'City': 'linqu',
#   'Lat': 36.5156,
#   'Lng': 118.5397,
#   'Max Temp': 24.74,
#   'Humidity': 49,
#   'Cloudiness': 0,
#   'Wind Speed': 1.55,
#   'Country': 'CN',
#   'Date': 1725675956},
#  {'City': 'masumbwe',
#   'Lat': -3.6333,
#   'Lng': 32.1833,
#   'Max Temp': 22.56,
#   'Humidity': 49,
#   'Cloudiness': 89,
#   'Wind Speed': 4.52,
#   'Country': 'TZ',
#   'Date': 1725675956},
#  {'City': 'dudinka',
#   'Lat': 69.4058,
#   'Lng': 86.1778,
#   'Max Temp': 5.59,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 6.89,
#   'Country': 'RU',
#   'Date': 1725675956},
#  {'City': 'saipan',
#   'Lat': 15.1355,
#   'Lng': 145.701,
#   'Max Temp': 32.39,
#   'Humidity': 70,
#   'Cloudiness': 40,
#   'Wind Speed': 4.12,
#   'Country': 'MP',
#   'Date': 1725675956},
#  {'City': 'bethel',
#   'Lat': 41.3712,
#   'Lng': -73.414,
#   'Max Temp': 19.41,
#   'Humidity': 94,
#   'Cloudiness': 0,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Date': 1725675833},
#  {'City': 'baotou',
#   'Lat': 40.6522,
#   'Lng': 109.8222,
#   'Max Temp': 17.13,
#   'Humidity': 68,
#   'Cloudiness': 4,
#   'Wind Speed': 1.72,
#   'Country': 'CN',
#   'Date': 1725675957},
#  {'City': 'atafu village',
#   'Lat': -8.5421,
#   'Lng': -172.5159,
#   'Max Temp': 27.62,
#   'Humidity': 78,
#   'Cloudiness': 19,
#   'Wind Speed': 6.45,
#   'Country': 'TK',
#   'Date': 1725675957},
#  {'City': 'south lake tahoe',
#   'Lat': 38.9332,
#   'Lng': -119.9844,
#   'Max Temp': 23.67,
#   'Humidity': 32,
#   'Cloudiness': 36,
#   'Wind Speed': 2.33,
#   'Country': 'US',
#   'Date': 1725675957},
#  {'City': 'thompson',
#   'Lat': 55.7435,
#   'Lng': -97.8558,
#   'Max Temp': 13.09,
#   'Humidity': 76,
#   'Cloudiness': 75,
#   'Wind Speed': 2.57,
#   'Country': 'CA',
#   'Date': 1725675823},
#  {'City': 'palmer',
#   'Lat': 42.1584,
#   'Lng': -72.3287,
#   'Max Temp': 18.75,
#   'Humidity': 82,
#   'Cloudiness': 75,
#   'Wind Speed': 3.6,
#   'Country': 'US',
#   'Date': 1725675957},
#  {'City': 'iqaluit',
#   'Lat': 63.7506,
#   'Lng': -68.5145,
#   'Max Temp': 3.85,
#   'Humidity': 75,
#   'Cloudiness': 75,
#   'Wind Speed': 2.57,
#   'Country': 'CA',
#   'Date': 1725675957},
#  {'City': 'blackmans bay',
#   'Lat': -43.0167,
#   'Lng': 147.3167,
#   'Max Temp': 14.29,
#   'Humidity': 58,
#   'Cloudiness': 91,
#   'Wind Speed': 1.79,
#   'Country': 'AU',
#   'Date': 1725675957},
#  {'City': 'tazovsky',
#   'Lat': 67.4667,
#   'Lng': 78.7,
#   'Max Temp': 5.59,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 8.36,
#   'Country': 'RU',
#   'Date': 1725675957},
#  {'City': 'ushuaia',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 3.81,
#   'Humidity': 81,
#   'Cloudiness': 75,
#   'Wind Speed': 6.17,
#   'Country': 'AR',
#   'Date': 1725675941},
#  {'City': 'brasileia',
#   'Lat': -11.0161,
#   'Lng': -68.7481,
#   'Max Temp': 27.13,
#   'Humidity': 40,
#   'Cloudiness': 0,
#   'Wind Speed': 0.67,
#   'Country': 'BR',
#   'Date': 1725675958},
#  {'City': 'papatowai',
#   'Lat': -46.5619,
#   'Lng': 169.4708,
#   'Max Temp': 9.57,
#   'Humidity': 63,
#   'Cloudiness': 100,
#   'Wind Speed': 9.88,
#   'Country': 'NZ',
#   'Date': 1725675958},
#  {'City': 'pemangkat',
#   'Lat': 1.1667,
#   'Lng': 108.9667,
#   'Max Temp': 29.7,
#   'Humidity': 67,
#   'Cloudiness': 21,
#   'Wind Speed': 2.18,
#   'Country': 'ID',
#   'Date': 1725675958},
#  {'City': 'vadso',
#   'Lat': 70.0744,
#   'Lng': 29.7487,
#   'Max Temp': 12.09,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 0.51,
#   'Country': 'NO',
#   'Date': 1725675958},
#  {'City': 'kodiak',
#   'Lat': 57.79,
#   'Lng': -152.4072,
#   'Max Temp': 13.73,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 3.09,
#   'Country': 'US',
#   'Date': 1725675958},
#  {'City': 'gonabad',
#   'Lat': 34.3529,
#   'Lng': 58.6837,
#   'Max Temp': 19.59,
#   'Humidity': 22,
#   'Cloudiness': 0,
#   'Wind Speed': 6.86,
#   'Country': 'IR',
#   'Date': 1725675958},
#  {'City': 'le lavandou',
#   'Lat': 43.137,
#   'Lng': 6.366,
#   'Max Temp': 22.9,
#   'Humidity': 76,
#   'Cloudiness': 75,
#   'Wind Speed': 2.57,
#   'Country': 'FR',
#   'Date': 1725675958},
#  {'City': 'olonkinbyen',
#   'Lat': 70.9221,
#   'Lng': -8.7187,
#   'Max Temp': 4.95,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 7.84,
#   'Country': 'SJ',
#   'Date': 1725675958},
#  {'City': "ust'-ilimsk",
#   'Lat': 58.0006,
#   'Lng': 102.6619,
#   'Max Temp': 12.76,
#   'Humidity': 58,
#   'Cloudiness': 100,
#   'Wind Speed': 1.59,
#   'Country': 'RU',
#   'Date': 1725675958},
#  {'City': 'kerikeri',
#   'Lat': -35.2268,
#   'Lng': 173.9474,
#   'Max Temp': 18.84,
#   'Humidity': 74,
#   'Cloudiness': 24,
#   'Wind Speed': 2.68,
#   'Country': 'NZ',
#   'Date': 1725675959},
#  {'City': 'hasaki',
#   'Lat': 35.7333,
#   'Lng': 140.8333,
#   'Max Temp': 28.27,
#   'Humidity': 76,
#   'Cloudiness': 16,
#   'Wind Speed': 3.26,
#   'Country': 'JP',
#   'Date': 1725675959},
#  {'City': 'keflavik',
#   'Lat': 64.0049,
#   'Lng': -22.5624,
#   'Max Temp': 9.24,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 10.29,
#   'Country': 'IS',
#   'Date': 1725675959},
#  {'City': 'edinburgh of the seven seas',
#   'Lat': -37.0676,
#   'Lng': -12.3116,
#   'Max Temp': 12.04,
#   'Humidity': 74,
#   'Cloudiness': 96,
#   'Wind Speed': 8.36,
#   'Country': 'SH',
#   'Date': 1725675959},
#  {'City': 'fortaleza',
#   'Lat': -3.7227,
#   'Lng': -38.5247,
#   'Max Temp': 26.23,
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 4.12,
#   'Country': 'BR',
#   'Date': 1725675725},
#  {'City': 'hithadhoo',
#   'Lat': -0.6,
#   'Lng': 73.0833,
#   'Max Temp': 28.37,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 2.81,
#   'Country': 'MV',
#   'Date': 1725675959},
#  {'City': 'taroa',
#   'Lat': 8.7058,
#   'Lng': 171.2275,
#   'Max Temp': 28.76,
#   'Humidity': 76,
#   'Cloudiness': 6,
#   'Wind Speed': 5.69,
#   'Country': 'MH',
#   'Date': 1725675959},
#  {'City': 'isafjordur',
#   'Lat': 66.0755,
#   'Lng': -23.124,
#   'Max Temp': 8.28,
#   'Humidity': 85,
#   'Cloudiness': 77,
#   'Wind Speed': 8.79,
#   'Country': 'IS',
#   'Date': 1725675959},
#  {'City': 'port-aux-francais',
#   'Lat': -49.35,
#   'Lng': 70.2167,
#   'Max Temp': 3.6,
#   'Humidity': 77,
#   'Cloudiness': 7,
#   'Wind Speed': 11.46,
#   'Country': 'TF',
#   'Date': 1725675959},
#  {'City': 'ancud',
#   'Lat': -41.8697,
#   'Lng': -73.8203,
#   'Max Temp': 8.38,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 5.56,
#   'Country': 'CL',
#   'Date': 1725675959},
#  {'City': 'nova xavantina',
#   'Lat': -14.6667,
#   'Lng': -52.35,
#   'Max Temp': 26.09,
#   'Humidity': 25,
#   'Cloudiness': 0,
#   'Wind Speed': 0.83,
#   'Country': 'BR',
#   'Date': 1725675960},
#  {'City': 'chake chake',
#   'Lat': -5.2459,
#   'Lng': 39.7666,
#   'Max Temp': 23.55,
#   'Humidity': 85,
#   'Cloudiness': 0,
#   'Wind Speed': 3.63,
#   'Country': 'TZ',
#   'Date': 1725675960},
#  {'City': 'toliara',
#   'Lat': -23.35,
#   'Lng': 43.6667,
#   'Max Temp': 21.12,
#   'Humidity': 77,
#   'Cloudiness': 0,
#   'Wind Speed': 4.27,
#   'Country': 'MG',
#   'Date': 1725675960},
#  {'City': 'timbuktu',
#   'Lat': 16.7735,
#   'Lng': -3.0074,
#   'Max Temp': 27.8,
#   'Humidity': 69,
#   'Cloudiness': 57,
#   'Wind Speed': 3.79,
#   'Country': 'ML',
#   'Date': 1725675960},
#  {'City': 'port mathurin',
#   'Lat': -19.6833,
#   'Lng': 63.4167,
#   'Max Temp': 22.06,
#   'Humidity': 71,
#   'Cloudiness': 60,
#   'Wind Speed': 9.21,
#   'Country': 'MU',
#   'Date': 1725675960},
#  {'City': 'kokkola',
#   'Lat': 63.8385,
#   'Lng': 23.1307,
#   'Max Temp': 16.07,
#   'Humidity': 97,
#   'Cloudiness': 0,
#   'Wind Speed': 3.09,
#   'Country': 'FI',
#   'Date': 1725675960},
#  {'City': 'suomussalmi',
#   'Lat': 64.8869,
#   'Lng': 28.9078,
#   'Max Temp': 14.8,
#   'Humidity': 95,
#   'Cloudiness': 0,
#   'Wind Speed': 3.35,
#   'Country': 'FI',
#   'Date': 1725675960},
#  {'City': 'college',
#   'Lat': 64.8569,
#   'Lng': -147.8028,
#   'Max Temp': 20.25,
#   'Humidity': 50,
#   'Cloudiness': 75,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Date': 1725675960},
#  {'City': 'dhidhdhoo',
#   'Lat': 6.8833,
#   'Lng': 73.1,
#   'Max Temp': 27.92,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 5.69,
#   'Country': 'MV',
#   'Date': 1725675960},
#  {'City': 'carnarvon',
#   'Lat': -24.8667,
#   'Lng': 113.6333,
#   'Max Temp': 19.54,
#   'Humidity': 37,
#   'Cloudiness': 0,
#   'Wind Speed': 10.19,
#   'Country': 'AU',
#   'Date': 1725675960},
#  {'City': 'bay roberts',
#   'Lat': 47.5999,
#   'Lng': -53.2648,
#   'Max Temp': 16.62,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 3.45,
#   'Country': 'CA',
#   'Date': 1725675960},
#  {'City': 'nizhnesortymskiy',
#   'Lat': 62.4397,
#   'Lng': 71.7603,
#   'Max Temp': 8.97,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 6.17,
#   'Country': 'RU',
#   'Date': 1725675960},
#  {'City': 'puerto aysen',
#   'Lat': -45.4,
#   'Lng': -72.7,
#   'Max Temp': 5.26,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 2.51,
#   'Country': 'CL',
#   'Date': 1725675961},
#  {'City': 'edmundston',
#   'Lat': 47.3737,
#   'Lng': -68.3251,
#   'Max Temp': 14.86,
#   'Humidity': 82,
#   'Cloudiness': 42,
#   'Wind Speed': 1.03,
#   'Country': 'CA',
#   'Date': 1725675961},
#  {'City': 'klyuchi',
#   'Lat': 52.2667,
#   'Lng': 79.1667,
#   'Max Temp': 9.77,
#   'Humidity': 86,
#   'Cloudiness': 96,
#   'Wind Speed': 2.54,
#   'Country': 'RU',
#   'Date': 1725675961},
#  {'City': 'akureyri',
#   'Lat': 65.6835,
#   'Lng': -18.0878,
#   'Max Temp': 12.96,
#   'Humidity': 58,
#   'Cloudiness': 75,
#   'Wind Speed': 11.32,
#   'Country': 'IS',
#   'Date': 1725675961},
#  {'City': 'yellowknife',
#   'Lat': 62.456,
#   'Lng': -114.3525,
#   'Max Temp': 21.29,
#   'Humidity': 54,
#   'Cloudiness': 20,
#   'Wind Speed': 2.06,
#   'Country': 'CA',
#   'Date': 1725675961},
#  {'City': 'barranca',
#   'Lat': -10.75,
#   'Lng': -77.7667,
#   'Max Temp': 16.11,
#   'Humidity': 84,
#   'Cloudiness': 97,
#   'Wind Speed': 2.11,
#   'Country': 'PE',
#   'Date': 1725675961},
#  {'City': 'albany',
#   'Lat': 42.6001,
#   'Lng': -73.9662,
#   'Max Temp': 19.77,
#   'Humidity': 69,
#   'Cloudiness': 1,
#   'Wind Speed': 1.87,
#   'Country': 'US',
#   'Date': 1725675961},
#  {'City': 'hawaiian paradise park',
#   'Lat': 19.5933,
#   'Lng': -154.9731,
#   'Max Temp': 28.18,
#   'Humidity': 76,
#   'Cloudiness': 75,
#   'Wind Speed': 5.14,
#   'Country': 'US',
#   'Date': 1725675961},
#  {'City': 'greenland',
#   'Lat': 43.0362,
#   'Lng': -70.8328,
#   'Max Temp': 17.9,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 3.6,
#   'Country': 'US',
#   'Date': 1725675961},
#  {'City': 'ulladulla',
#   'Lat': -35.35,
#   'Lng': 150.4667,
#   'Max Temp': 14.2,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 2.98,
#   'Country': 'AU',
#   'Date': 1725675961},
#  {'City': "port saint john's",
#   'Lat': -31.6229,
#   'Lng': 29.5448,
#   'Max Temp': 15.44,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 1.22,
#   'Country': 'ZA',
#   'Date': 1725675961},
#  {'City': 'castillos',
#   'Lat': -34.1667,
#   'Lng': -53.8333,
#   'Max Temp': 8.88,
#   'Humidity': 95,
#   'Cloudiness': 90,
#   'Wind Speed': 2.35,
#   'Country': 'UY',
#   'Date': 1725675962},
#  {'City': 'dauphin',
#   'Lat': 51.1494,
#   'Lng': -100.0502,
#   'Max Temp': 11.08,
#   'Humidity': 82,
#   'Cloudiness': 0,
#   'Wind Speed': 3.09,
#   'Country': 'CA',
#   'Date': 1725675962},
#  {'City': 'alice springs',
#   'Lat': -23.7,
#   'Lng': 133.8833,
#   'Max Temp': 24.75,
#   'Humidity': 33,
#   'Cloudiness': 4,
#   'Wind Speed': 6.17,
#   'Country': 'AU',
#   'Date': 1725675962},
#  {'City': 'mount hawthorn',
#   'Lat': -31.9217,
#   'Lng': 115.8328,
#   'Max Temp': 17.74,
#   'Humidity': 70,
#   'Cloudiness': 20,
#   'Wind Speed': 2.24,
#   'Country': 'AU',
#   'Date': 1725675962},
#  {'City': 'margaret river',
#   'Lat': -33.95,
#   'Lng': 115.0667,
#   'Max Temp': 15.36,
#   'Humidity': 62,
#   'Cloudiness': 64,
#   'Wind Speed': 6.04,
#   'Country': 'AU',
#   'Date': 1725675962},
#  {'City': 'pubal',
#   'Lat': 37.2917,
#   'Lng': 127.5078,
#   'Max Temp': 28.69,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 1.54,
#   'Country': 'KR',
#   'Date': 1725675962},
#  {'City': 'ribeira grande',
#   'Lat': 38.5167,
#   'Lng': -28.7,
#   'Max Temp': 22.1,
#   'Humidity': 63,
#   'Cloudiness': 83,
#   'Wind Speed': 3.13,
#   'Country': 'PT',
#   'Date': 1725675962},
#  {'City': 'codrington',
#   'Lat': -38.2667,
#   'Lng': 141.9667,
#   'Max Temp': 14.19,
#   'Humidity': 71,
#   'Cloudiness': 44,
#   'Wind Speed': 8.03,
#   'Country': 'AU',
#   'Date': 1725675962},
#  {'City': 'pacific grove',
#   'Lat': 36.6177,
#   'Lng': -121.9166,
#   'Max Temp': 22.82,
#   'Humidity': 82,
#   'Cloudiness': 0,
#   'Wind Speed': 2.24,
#   'Country': 'US',
#   'Date': 1725675962},
#  {'City': 'arica',
#   'Lat': -18.475,
#   'Lng': -70.3042,
#   'Max Temp': 16.13,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 2.06,
#   'Country': 'CL',
#   'Date': 1725675708},
#  {'City': 'chimbarongo',
#   'Lat': -34.7,
#   'Lng': -71.05,
#   'Max Temp': 13.5,
#   'Humidity': 67,
#   'Cloudiness': 100,
#   'Wind Speed': 1.5,
#   'Country': 'CL',
#   'Date': 1725675962},
#  {'City': 'la mira',
#   'Lat': 18.035,
#   'Lng': -102.3266,
#   'Max Temp': 27.1,
#   'Humidity': 86,
#   'Cloudiness': 93,
#   'Wind Speed': 3.08,
#   'Country': 'MX',
#   'Date': 1725675963},
#  {'City': 'sake',
#   'Lat': -1.5736,
#   'Lng': 29.045,
#   'Max Temp': 17.06,
#   'Humidity': 85,
#   'Cloudiness': 30,
#   'Wind Speed': 0.28,
#   'Country': 'CD',
#   'Date': 1725675963},
#  {'City': 'arraial do cabo',
#   'Lat': -22.9661,
#   'Lng': -42.0278,
#   'Max Temp': 22.31,
#   'Humidity': 88,
#   'Cloudiness': 28,
#   'Wind Speed': 2.48,
#   'Country': 'BR',
#   'Date': 1725675963},
#  {'City': 'sylt-ost',
#   'Lat': 54.8833,
#   'Lng': 8.35,
#   'Max Temp': 19.05,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 6.69,
#   'Country': 'DE',
#   'Date': 1725675963},
#  {'City': 'beohari',
#   'Lat': 24.05,
#   'Lng': 81.3833,
#   'Max Temp': 26.4,
#   'Humidity': 83,
#   'Cloudiness': 98,
#   'Wind Speed': 0.83,
#   'Country': 'IN',
#   'Date': 1725675963},
#  {'City': 'shakawe',
#   'Lat': -18.3667,
#   'Lng': 21.85,
#   'Max Temp': 14.89,
#   'Humidity': 29,
#   'Cloudiness': 3,
#   'Wind Speed': 2.71,
#   'Country': 'BW',
#   'Date': 1725675963},
#  {'City': 'hermanus',
#   'Lat': -34.4187,
#   'Lng': 19.2345,
#   'Max Temp': 4.33,
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 3.19,
#   'Country': 'ZA',
#   'Date': 1725675963},
#  {'City': 'kadi',
#   'Lat': 23.3,
#   'Lng': 72.3333,
#   'Max Temp': 26.08,
#   'Humidity': 88,
#   'Cloudiness': 99,
#   'Wind Speed': 2.36,
#   'Country': 'IN',
#   'Date': 1725675963},
#  {'City': 'vila velha',
#   'Lat': -20.3297,
#   'Lng': -40.2925,
#   'Max Temp': 22.75,
#   'Humidity': 92,
#   'Cloudiness': 20,
#   'Wind Speed': 1.03,
#   'Country': 'BR',
#   'Date': 1725675817},
#  {'City': 'pukchil-lodongjagu',
#   'Lat': 40.2019,
#   'Lng': 125.7483,
#   'Max Temp': 24.84,
#   'Humidity': 59,
#   'Cloudiness': 27,
#   'Wind Speed': 0.12,
#   'Country': 'KP',
#   'Date': 1725675964},
#  {'City': 'togur',
#   'Lat': 58.3631,
#   'Lng': 82.8265,
#   'Max Temp': 8.11,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 1.99,
#   'Country': 'RU',
#   'Date': 1725675964},
#  {'City': 'labrador city',
#   'Lat': 52.9463,
#   'Lng': -66.9114,
#   'Max Temp': 16.77,
#   'Humidity': 53,
#   'Cloudiness': 40,
#   'Wind Speed': 8.49,
#   'Country': 'CA',
#   'Date': 1725675964},
#  {'City': 'susuman',
#   'Lat': 62.7833,
#   'Lng': 148.1667,
#   'Max Temp': 6.27,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 2.86,
#   'Country': 'RU',
#   'Date': 1725675964},
#  {'City': 'port lincoln',
#   'Lat': -34.7333,
#   'Lng': 135.8667,
#   'Max Temp': 16.3,
#   'Humidity': 56,
#   'Cloudiness': 14,
#   'Wind Speed': 6.62,
#   'Country': 'AU',
#   'Date': 1725675964},
#  {'City': "sos'va",
#   'Lat': 59.1766,
#   'Lng': 61.8558,
#   'Max Temp': 8.1,
#   'Humidity': 88,
#   'Cloudiness': 97,
#   'Wind Speed': 2.57,
#   'Country': 'RU',
#   'Date': 1725675964},
#  {'City': 'motueka',
#   'Lat': -41.1333,
#   'Lng': 173.0167,
#   'Max Temp': 19.5,
#   'Humidity': 53,
#   'Cloudiness': 14,
#   'Wind Speed': 2.22,
#   'Country': 'NZ',
#   'Date': 1725675964},
#  {'City': 'monte santo',
#   'Lat': -10.4378,
#   'Lng': -39.3328,
#   'Max Temp': 18.93,
#   'Humidity': 74,
#   'Cloudiness': 10,
#   'Wind Speed': 3.98,
#   'Country': 'BR',
#   'Date': 1725675964},
#  {'City': 'invercargill',
#   'Lat': -46.4,
#   'Lng': 168.35,
#   'Max Temp': 8.9,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 8.05,
#   'Country': 'NZ',
#   'Date': 1725675964},
#  {'City': "kapa'a",
#   'Lat': 22.0752,
#   'Lng': -159.319,
#   'Max Temp': 29.18,
#   'Humidity': 65,
#   'Cloudiness': 0,
#   'Wind Speed': 5.14,
#   'Country': 'US',
#   'Date': 1725675964},
#  {'City': 'tual',
#   'Lat': -5.6667,
#   'Lng': 132.75,
#   'Max Temp': 26.67,
#   'Humidity': 84,
#   'Cloudiness': 93,
#   'Wind Speed': 8.66,
#   'Country': 'ID',
#   'Date': 1725675964},
#  {'City': 'whitehorse',
#   'Lat': 60.7161,
#   'Lng': -135.0538,
#   'Max Temp': 14.43,
#   'Humidity': 57,
#   'Cloudiness': 75,
#   'Wind Speed': 7.2,
#   'Country': 'CA',
#   'Date': 1725675964},
#  {'City': 'talnakh',
#   'Lat': 69.4865,
#   'Lng': 88.3972,
#   'Max Temp': 6.87,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 2.15,
#   'Country': 'RU',
#   'Date': 1725675965},
#  {'City': 'bredasdorp',
#   'Lat': -34.5322,
#   'Lng': 20.0403,
#   'Max Temp': 6.3,
#   'Humidity': 85,
#   'Cloudiness': 0,
#   'Wind Speed': 1.4,
#   'Country': 'ZA',
#   'Date': 1725675965},
#  {'City': 'chelghoum el aid',
#   'Lat': 36.1629,
#   'Lng': 6.1665,
#   'Max Temp': 24.74,
#   'Humidity': 52,
#   'Cloudiness': 61,
#   'Wind Speed': 3.74,
#   'Country': 'DZ',
#   'Date': 1725675965},
#  {'City': 'anadyr',
#   'Lat': 64.75,
#   'Lng': 177.4833,
#   'Max Temp': 11.28,
#   'Humidity': 76,
#   'Cloudiness': 20,
#   'Wind Speed': 13.86,
#   'Country': 'RU',
#   'Date': 1725675965},
#  {'City': 'siparia',
#   'Lat': 10.1333,
#   'Lng': -61.5,
#   'Max Temp': 27.09,
#   'Humidity': 84,
#   'Cloudiness': 27,
#   'Wind Speed': 3.89,
#   'Country': 'TT',
#   'Date': 1725675965},
#  {'City': 'chibougamau',
#   'Lat': 49.9168,
#   'Lng': -74.3659,
#   'Max Temp': 10.79,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 3.6,
#   'Country': 'CA',
#   'Date': 1725675965},
#  {'City': 'zheleznogorsk-ilimskiy',
#   'Lat': 56.5768,
#   'Lng': 104.1217,
#   'Max Temp': 10.87,
#   'Humidity': 62,
#   'Cloudiness': 100,
#   'Wind Speed': 1.24,
#   'Country': 'RU',
#   'Date': 1725675965},
#  {'City': 'atasu',
#   'Lat': 48.6814,
#   'Lng': 71.6433,
#   'Max Temp': 8.22,
#   'Humidity': 70,
#   'Cloudiness': 78,
#   'Wind Speed': 4.07,
#   'Country': 'KZ',
#   'Date': 1725675965},
#  {'City': 'lazaro cardenas',
#   'Lat': 17.9583,
#   'Lng': -102.2,
#   'Max Temp': 28.24,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 3.22,
#   'Country': 'MX',
#   'Date': 1725675741},
#  {'City': 'avarua',
#   'Lat': -21.2078,
#   'Lng': -159.775,
#   'Max Temp': 26.03,
#   'Humidity': 78,
#   'Cloudiness': 40,
#   'Wind Speed': 8.75,
#   'Country': 'CK',
#   'Date': 1725675908},
#  {'City': 'afaahiti',
#   'Lat': -17.75,
#   'Lng': -149.2833,
#   'Max Temp': 22.84,
#   'Humidity': 81,
#   'Cloudiness': 79,
#   'Wind Speed': 10.16,
#   'Country': 'PF',
#   'Date': 1725675966},
#  {'City': 'ulanhot',
#   'Lat': 46.0833,
#   'Lng': 122.0833,
#   'Max Temp': 23.82,
#   'Humidity': 52,
#   'Cloudiness': 0,
#   'Wind Speed': 6.92,
#   'Country': 'CN',
#   'Date': 1725675966},
#  {'City': 'bera',
#   'Lat': 24.0833,
#   'Lng': 89.6167,
#   'Max Temp': 30.83,
#   'Humidity': 66,
#   'Cloudiness': 21,
#   'Wind Speed': 0.83,
#   'Country': 'BD',
#   'Date': 1725675966},
#  {'City': 'jijel',
#   'Lat': 36.8205,
#   'Lng': 5.7667,
#   'Max Temp': 30.97,
#   'Humidity': 35,
#   'Cloudiness': 0,
#   'Wind Speed': 6.69,
#   'Country': 'DZ',
#   'Date': 1725675966},
#  {'City': 'west island',
#   'Lat': -12.1568,
#   'Lng': 96.8225,
#   'Max Temp': 27.99,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 7.2,
#   'Country': 'CC',
#   'Date': 1725675966},
#  {'City': 'flying fish cove',
#   'Lat': -10.4217,
#   'Lng': 105.6791,
#   'Max Temp': 26.82,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 7.72,
#   'Country': 'CX',
#   'Date': 1725675966},
#  {'City': 'lae',
#   'Lat': -6.7221,
#   'Lng': 146.9847,
#   'Max Temp': 23.92,
#   'Humidity': 86,
#   'Cloudiness': 95,
#   'Wind Speed': 1.52,
#   'Country': 'PG',
#   'Date': 1725675966},
#  {'City': 'puerto baquerizo moreno',
#   'Lat': -0.9,
#   'Lng': -89.6,
#   'Max Temp': 20.98,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 4.66,
#   'Country': 'EC',
#   'Date': 1725675966},
#  {'City': 'pindiga',
#   'Lat': 9.9833,
#   'Lng': 10.9333,
#   'Max Temp': 20.26,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 3.14,
#   'Country': 'NG',
#   'Date': 1725675966},
#  {'City': 'champoton',
#   'Lat': 19.35,
#   'Lng': -90.7167,
#   'Max Temp': 26.39,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 2.74,
#   'Country': 'MX',
#   'Date': 1725675967},
#  {'City': 'bataipora',
#   'Lat': -22.2953,
#   'Lng': -53.2711,
#   'Max Temp': 23.84,
#   'Humidity': 39,
#   'Cloudiness': 0,
#   'Wind Speed': 2.47,
#   'Country': 'BR',
#   'Date': 1725675967},
#  {'City': 'tura',
#   'Lat': 25.5198,
#   'Lng': 90.2201,
#   'Max Temp': 28.13,
#   'Humidity': 82,
#   'Cloudiness': 81,
#   'Wind Speed': 0.49,
#   'Country': 'IN',
#   'Date': 1725675967},
#  {'City': 'sisimiut',
#   'Lat': 66.9395,
#   'Lng': -53.6735,
#   'Max Temp': 1.6,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 4.38,
#   'Country': 'GL',
#   'Date': 1725675967},
#  {'City': 'qaqortoq',
#   'Lat': 60.7167,
#   'Lng': -46.0333,
#   'Max Temp': 3.77,
#   'Humidity': 79,
#   'Cloudiness': 6,
#   'Wind Speed': 3.33,
#   'Country': 'GL',
#   'Date': 1725675967},
#  {'City': 'kabalo',
#   'Lat': -6.05,
#   'Lng': 26.9167,
#   'Max Temp': 25.11,
#   'Humidity': 58,
#   'Cloudiness': 1,
#   'Wind Speed': 1.02,
#   'Country': 'CD',
#   'Date': 1725675967},
#  {'City': 'badger',
#   'Lat': 64.8,
#   'Lng': -147.5333,
#   'Max Temp': 20.2,
#   'Humidity': 51,
#   'Cloudiness': 75,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Date': 1725675967},
#  {'City': 'cova figueira',
#   'Lat': 14.8905,
#   'Lng': -24.2934,
#   'Max Temp': 20.25,
#   'Humidity': 86,
#   'Cloudiness': 86,
#   'Wind Speed': 3.56,
#   'Country': 'CV',
#   'Date': 1725675967},
#  {'City': 'georgetown',
#   'Lat': 5.4112,
#   'Lng': 100.3354,
#   'Max Temp': 29.96,
#   'Humidity': 83,
#   'Cloudiness': 20,
#   'Wind Speed': 3.6,
#   'Country': 'MY',
#   'Date': 1725675933},
#  {'City': 'puerto ayora',
#   'Lat': -0.7393,
#   'Lng': -90.3518,
#   'Max Temp': 20.86,
#   'Humidity': 95,
#   'Cloudiness': 96,
#   'Wind Speed': 2.24,
#   'Country': 'EC',
#   'Date': 1725675967},
#  {'City': 'igarka',
#   'Lat': 67.4667,
#   'Lng': 86.5833,
#   'Max Temp': 7.84,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 4.11,
#   'Country': 'RU',
#   'Date': 1725675967},
#  {'City': 'wailua homesteads',
#   'Lat': 22.0669,
#   'Lng': -159.378,
#   'Max Temp': 28.44,
#   'Humidity': 67,
#   'Cloudiness': 0,
#   'Wind Speed': 5.14,
#   'Country': 'US',
#   'Date': 1725675967},
#  {'City': 'camana',
#   'Lat': -16.6228,
#   'Lng': -72.7111,
#   'Max Temp': 15.45,
#   'Humidity': 81,
#   'Cloudiness': 65,
#   'Wind Speed': 3.06,
#   'Country': 'PE',
#   'Date': 1725675968},
#  {'City': 'fenoarivo atsinanana',
#   'Lat': -17.3667,
#   'Lng': 49.4167,
#   'Max Temp': 20.19,
#   'Humidity': 94,
#   'Cloudiness': 90,
#   'Wind Speed': 2.73,
#   'Country': 'MG',
#   'Date': 1725675968},
#  {'City': "nar'yan-mar",
#   'Lat': 67.6713,
#   'Lng': 53.087,
#   'Max Temp': 10.2,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 4.59,
#   'Country': 'RU',
#   'Date': 1725675730},
#  {'City': 'masterton',
#   'Lat': -40.9597,
#   'Lng': 175.6575,
#   'Max Temp': 15.28,
#   'Humidity': 79,
#   'Cloudiness': 52,
#   'Wind Speed': 6.76,
#   'Country': 'NZ',
#   'Date': 1725675968},
#  {'City': 'kailua-kona',
#   'Lat': 19.6406,
#   'Lng': -155.9956,
#   'Max Temp': 28.98,
#   'Humidity': 71,
#   'Cloudiness': 20,
#   'Wind Speed': 3.6,
#   'Country': 'US',
#   'Date': 1725675968},
#  {'City': 'east london',
#   'Lat': -33.0153,
#   'Lng': 27.9116,
#   'Max Temp': 15.3,
#   'Humidity': 69,
#   'Cloudiness': 87,
#   'Wind Speed': 2.1,
#   'Country': 'ZA',
#   'Date': 1725675968},
#  {'City': 'dompu',
#   'Lat': -8.5356,
#   'Lng': 118.4622,
#   'Max Temp': 31.62,
#   'Humidity': 56,
#   'Cloudiness': 59,
#   'Wind Speed': 3.35,
#   'Country': 'ID',
#   'Date': 1725675968},
#  {'City': 'fisterra',
#   'Lat': 42.9049,
#   'Lng': -9.2629,
#   'Max Temp': 15.53,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 1.17,
#   'Country': 'ES',
#   'Date': 1725675968},
#  {'City': 'hamilton',
#   'Lat': 39.1834,
#   'Lng': -84.5333,
#   'Max Temp': 19.99,
#   'Humidity': 77,
#   'Cloudiness': 0,
#   'Wind Speed': 3.6,
#   'Country': 'US',
#   'Date': 1725675893},
#  {'City': 'bamyan',
#   'Lat': 34.75,
#   'Lng': 67.25,
#   'Max Temp': 7.49,
#   'Humidity': 31,
#   'Cloudiness': 0,
#   'Wind Speed': 2.12,
#   'Country': 'AF',
#   'Date': 1725675969},
#  {'City': 'lerwick',
#   'Lat': 60.1545,
#   'Lng': -1.1494,
#   'Max Temp': 13.45,
#   'Humidity': 97,
#   'Cloudiness': 97,
#   'Wind Speed': 2.69,
#   'Country': 'GB',
#   'Date': 1725675969},
#  {'City': 'la maddalena',
#   'Lat': 41.2142,
#   'Lng': 9.4083,
#   'Max Temp': 24.7,
#   'Humidity': 84,
#   'Cloudiness': 1,
#   'Wind Speed': 3.82,
#   'Country': 'IT',
#   'Date': 1725675969},
#  {'City': 'lompoc',
#   'Lat': 34.6391,
#   'Lng': -120.4579,
#   'Max Temp': 22.3,
#   'Humidity': 61,
#   'Cloudiness': 0,
#   'Wind Speed': 4.63,
#   'Country': 'US',
#   'Date': 1725675969},
#  {'City': 'dapa',
#   'Lat': 9.7594,
#   'Lng': 126.0531,
#   'Max Temp': 29.82,
#   'Humidity': 70,
#   'Cloudiness': 87,
#   'Wind Speed': 3.84,
#   'Country': 'PH',
#   'Date': 1725675969},
#  {'City': 'minas de marcona',
#   'Lat': -15.2119,
#   'Lng': -75.1103,
#   'Max Temp': 11.96,
#   'Humidity': 74,
#   'Cloudiness': 81,
#   'Wind Speed': 4.82,
#   'Country': 'PE',
#   'Date': 1725675969},
#  {'City': 'bilibino',
#   'Lat': 68.0546,
#   'Lng': 166.4372,
#   'Max Temp': 10.68,
#   'Humidity': 63,
#   'Cloudiness': 100,
#   'Wind Speed': 1.64,
#   'Country': 'RU',
#   'Date': 1725675969},
#  {'City': 'goundam',
#   'Lat': 16.4145,
#   'Lng': -3.6708,
#   'Max Temp': 27.27,
#   'Humidity': 74,
#   'Cloudiness': 75,
#   'Wind Speed': 4.77,
#   'Country': 'ML',
#   'Date': 1725675969},
#  {'City': 'taltal',
#   'Lat': -25.4,
#   'Lng': -70.4833,
#   'Max Temp': 14.42,
#   'Humidity': 82,
#   'Cloudiness': 0,
#   'Wind Speed': 2.05,
#   'Country': 'CL',
#   'Date': 1725675620},
#  {'City': 'okhotsk',
#   'Lat': 59.3833,
#   'Lng': 143.3,
#   'Max Temp': 9.94,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 3.41,
#   'Country': 'RU',
#   'Date': 1725675969},
#  {'City': 'isangel',
#   'Lat': -19.55,
#   'Lng': 169.2667,
#   'Max Temp': 27.06,
#   'Humidity': 50,
#   'Cloudiness': 40,
#   'Wind Speed': 6.17,
#   'Country': 'VU',
#   'Date': 1725675970},
#  {'City': 'aginskoye',
#   'Lat': 51.1,
#   'Lng': 114.53,
#   'Max Temp': 17.87,
#   'Humidity': 42,
#   'Cloudiness': 26,
#   'Wind Speed': 1.96,
#   'Country': 'RU',
#   'Date': 1725675970},
#  {'City': 'murtosa',
#   'Lat': 40.7553,
#   'Lng': -8.6585,
#   'Max Temp': 13.93,
#   'Humidity': 88,
#   'Cloudiness': 95,
#   'Wind Speed': 4.34,
#   'Country': 'PT',
#   'Date': 1725675970},
#  {'City': 'waddan',
#   'Lat': 29.1614,
#   'Lng': 16.139,
#   'Max Temp': 31.35,
#   'Humidity': 32,
#   'Cloudiness': 100,
#   'Wind Speed': 2.99,
#   'Country': 'LY',
#   'Date': 1725675970},
#  {'City': 'raseiniai',
#   'Lat': 55.3736,
#   'Lng': 23.1217,
#   'Max Temp': 13.64,
#   'Humidity': 54,
#   'Cloudiness': 32,
#   'Wind Speed': 3.17,
#   'Country': 'LT',
#   'Date': 1725675970},
#  {'City': 'punta arenas',
#   'Lat': -53.15,
#   'Lng': -70.9167,
#   'Max Temp': 3.06,
#   'Humidity': 87,
#   'Cloudiness': 0,
#   'Wind Speed': 6.69,
#   'Country': 'CL',
#   'Date': 1725675709},
#  {'City': 'rawson',
#   'Lat': -43.3002,
#   'Lng': -65.1023,
#   'Max Temp': 10.16,
#   'Humidity': 37,
#   'Cloudiness': 0,
#   'Wind Speed': 2.06,
#   'Country': 'AR',
#   'Date': 1725675970},
#  {'City': 'raduzhnyy',
#   'Lat': 62.0961,
#   'Lng': 77.475,
#   'Max Temp': 9.3,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 4.63,
#   'Country': 'RU',
#   'Date': 1725675970},
#  {'City': 'luderitz',
#   'Lat': -26.6481,
#   'Lng': 15.1594,
#   'Max Temp': 11.11,
#   'Humidity': 74,
#   'Cloudiness': 0,
#   'Wind Speed': 7.77,
#   'Country': 'NA',
#   'Date': 1725675971},
#  {'City': 'horta',
#   'Lat': 38.5333,
#   'Lng': -28.6333,
#   'Max Temp': 21.68,
#   'Humidity': 63,
#   'Cloudiness': 65,
#   'Wind Speed': 3.13,
#   'Country': 'PT',
#   'Date': 1725675971},
#  {'City': 'rosso',
#   'Lat': 16.4986,
#   'Lng': -15.8153,
#   'Max Temp': 25.15,
#   'Humidity': 70,
#   'Cloudiness': 54,
#   'Wind Speed': 5.53,
#   'Country': 'SN',
#   'Date': 1725675971},
#  {'City': 'moses lake',
#   'Lat': 47.1301,
#   'Lng': -119.2781,
#   'Max Temp': 34.2,
#   'Humidity': 17,
#   'Cloudiness': 0,
#   'Wind Speed': 1.54,
#   'Country': 'US',
#   'Date': 1725675971},
#  {'City': 'geraldton',
#   'Lat': -28.7667,
#   'Lng': 114.6,
#   'Max Temp': 18.23,
#   'Humidity': 72,
#   'Cloudiness': 0,
#   'Wind Speed': 4.12,
#   'Country': 'AU',
#   'Date': 1725675971},
#  {'City': 'fonte boa',
#   'Lat': -2.4959,
#   'Lng': -66.2662,
#   'Max Temp': 26.66,
#   'Humidity': 59,
#   'Cloudiness': 71,
#   'Wind Speed': 0.77,
#   'Country': 'BR',
#   'Date': 1725675971},
#  {'City': 'mendi',
#   'Lat': -6.1761,
#   'Lng': 143.6513,
#   'Max Temp': 16.4,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 1.51,
#   'Country': 'PG',
#   'Date': 1725675971},
#  {'City': 'ippy',
#   'Lat': 6.2679,
#   'Lng': 21.2247,
#   'Max Temp': 20.84,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 1.63,
#   'Country': 'CF',
#   'Date': 1725675971},
#  {'City': 'pitimbu',
#   'Lat': -7.4706,
#   'Lng': -34.8086,
#   'Max Temp': 23.85,
#   'Humidity': 84,
#   'Cloudiness': 42,
#   'Wind Speed': 4.76,
#   'Country': 'BR',
#   'Date': 1725675971},
#  {'City': 'inhambane',
#   'Lat': -23.865,
#   'Lng': 35.3833,
#   'Max Temp': 21.31,
#   'Humidity': 90,
#   'Cloudiness': 1,
#   'Wind Speed': 1.95,
#   'Country': 'MZ',
#   'Date': 1725675971},
#  {'City': 'xilin hot',
#   'Lat': 43.9667,
#   'Lng': 116.0333,
#   'Max Temp': 16.47,
#   'Humidity': 62,
#   'Cloudiness': 0,
#   'Wind Speed': 3.83,
#   'Country': 'CN',
#   'Date': 1725675971},
#  {'City': 'hami',
#   'Lat': 42.8,
#   'Lng': 93.45,
#   'Max Temp': 26.68,
#   'Humidity': 18,
#   'Cloudiness': 0,
#   'Wind Speed': 3.58,
#   'Country': 'CN',
#   'Date': 1725675972},
#  {'City': 'crane',
#   'Lat': 31.3974,
#   'Lng': -102.3501,
#   'Max Temp': 27.13,
#   'Humidity': 43,
#   'Cloudiness': 70,
#   'Wind Speed': 6.01,
#   'Country': 'US',
#   'Date': 1725675972},
#  {'City': 'cadale',
#   'Lat': 2.7603,
#   'Lng': 46.3222,
#   'Max Temp': 25.2,
#   'Humidity': 84,
#   'Cloudiness': 24,
#   'Wind Speed': 6.99,
#   'Country': 'SO',
#   'Date': 1725675972},
#  {'City': 'saudarkrokur',
#   'Lat': 65.7461,
#   'Lng': -19.6394,
#   'Max Temp': 9.89,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 10.42,
#   'Country': 'IS',
#   'Date': 1725675972},
#  {'City': 'uturoa',
#   'Lat': -16.7333,
#   'Lng': -151.4333,
#   'Max Temp': 25.84,
#   'Humidity': 69,
#   'Cloudiness': 17,
#   'Wind Speed': 8.83,
#   'Country': 'PF',
#   'Date': 1725675972},
#  {'City': 'jamestown',
#   'Lat': 42.097,
#   'Lng': -79.2353,
#   'Max Temp': 17.79,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 3.6,
#   'Country': 'US',
#   'Date': 1725675840},
#  {'City': 'sao jose da coroa grande',
#   'Lat': -8.8978,
#   'Lng': -35.1478,
#   'Max Temp': 23.97,
#   'Humidity': 80,
#   'Cloudiness': 16,
#   'Wind Speed': 4.31,
#   'Country': 'BR',
#   'Date': 1725675972},
#  {'City': 'new norfolk',
#   'Lat': -42.7826,
#   'Lng': 147.0587,
#   'Max Temp': 14.95,
#   'Humidity': 65,
#   'Cloudiness': 70,
#   'Wind Speed': 4.41,
#   'Country': 'AU',
#   'Date': 1725675972},
#  {'City': 'gariaband',
#   'Lat': 20.635,
#   'Lng': 82.0614,
#   'Max Temp': 25.66,
#   'Humidity': 90,
#   'Cloudiness': 52,
#   'Wind Speed': 0.75,
#   'Country': 'IN',
#   'Date': 1725675972},
#  {'City': 'xindi',
#   'Lat': 29.8167,
#   'Lng': 113.4667,
#   'Max Temp': 30.41,
#   'Humidity': 66,
#   'Cloudiness': 100,
#   'Wind Speed': 4.22,
#   'Country': 'CN',
#   'Date': 1725675972},
#  {'City': 'mount isa',
#   'Lat': -20.7333,
#   'Lng': 139.5,
#   'Max Temp': 29.87,
#   'Humidity': 32,
#   'Cloudiness': 0,
#   'Wind Speed': 5.14,
#   'Country': 'AU',
#   'Date': 1725675973},
#  {'City': 'mejit',
#   'Lat': 10.2753,
#   'Lng': 170.8646,
#   'Max Temp': 28.65,
#   'Humidity': 74,
#   'Cloudiness': 2,
#   'Wind Speed': 5.4,
#   'Country': 'MH',
#   'Date': 1725675973},
#  {'City': 'porto franco',
#   'Lat': -6.3383,
#   'Lng': -47.3992,
#   'Max Temp': 25.68,
#   'Humidity': 33,
#   'Cloudiness': 3,
#   'Wind Speed': 1.26,
#   'Country': 'BR',
#   'Date': 1725675973},
#  {'City': 'remire-montjoly',
#   'Lat': 4.9167,
#   'Lng': -52.2667,
#   'Max Temp': 26.02,
#   'Humidity': 89,
#   'Cloudiness': 0,
#   'Wind Speed': 1.03,
#   'Country': 'GF',
#   'Date': 1725675973},
#  {'City': 'longyearbyen',
#   'Lat': 78.2186,
#   'Lng': 15.6401,
#   'Max Temp': 4.91,
#   'Humidity': 81,
#   'Cloudiness': 75,
#   'Wind Speed': 5.14,
#   'Country': 'SJ',
#   'Date': 1725675973},
#  {'City': 'holualoa',
#   'Lat': 19.6228,
#   'Lng': -155.9522,
#   'Max Temp': 26.91,
#   'Humidity': 78,
#   'Cloudiness': 20,
#   'Wind Speed': 3.6,
#   'Country': 'US',
#   'Date': 1725675973},
#  {'City': 'rio grande',
#   'Lat': -32.035,
#   'Lng': -52.0986,
#   'Max Temp': 12.33,
#   'Humidity': 90,
#   'Cloudiness': 19,
#   'Wind Speed': 4.5,
#   'Country': 'BR',
#   'Date': 1725675973},
#  {'City': 'chonchi',
#   'Lat': -42.6128,
#   'Lng': -73.8092,
#   'Max Temp': 7.84,
#   'Humidity': 96,
#   'Cloudiness': 73,
#   'Wind Speed': 1.81,
#   'Country': 'CL',
#   'Date': 1725675973},
#  {'City': 'imbert',
#   'Lat': 19.7537,
#   'Lng': -70.8291,
#   'Max Temp': 26.05,
#   'Humidity': 95,
#   'Cloudiness': 2,
#   'Wind Speed': 1.46,
#   'Country': 'DO',
#   'Date': 1725675973},
#  {'City': 'brisas de zicatela',
#   'Lat': 15.8369,
#   'Lng': -97.0419,
#   'Max Temp': 29.29,
#   'Humidity': 89,
#   'Cloudiness': 75,
#   'Wind Speed': 1.54,
#   'Country': 'MX',
#   'Date': 1725675973},
#  {'City': 'egilsstadir',
#   'Lat': 65.2653,
#   'Lng': -14.3948,
#   'Max Temp': 12.95,
#   'Humidity': 54,
#   'Cloudiness': 0,
#   'Wind Speed': 3.09,
#   'Country': 'IS',
#   'Date': 1725675973},
#  {'City': 'nili',
#   'Lat': 33.7218,
#   'Lng': 66.1302,
#   'Max Temp': 15.39,
#   'Humidity': 17,
#   'Cloudiness': 0,
#   'Wind Speed': 3.26,
#   'Country': 'AF',
#   'Date': 1725675974},
#  {'City': 'basoko',
#   'Lat': 1.2391,
#   'Lng': 23.616,
#   'Max Temp': 21.49,
#   'Humidity': 96,
#   'Cloudiness': 30,
#   'Wind Speed': 0.98,
#   'Country': 'CD',
#   'Date': 1725675974},
#  {'City': 'black point',
#   'Lat': -34.6187,
#   'Lng': 137.8972,
#   'Max Temp': 15.8,
#   'Humidity': 63,
#   'Cloudiness': 0,
#   'Wind Speed': 5.06,
#   'Country': 'AU',
#   'Date': 1725675974},
#  {'City': 'bride',
#   'Lat': 54.3826,
#   'Lng': -4.3892,
#   'Max Temp': 14.86,
#   'Humidity': 95,
#   'Cloudiness': 15,
#   'Wind Speed': 5.4,
#   'Country': 'IM',
#   'Date': 1725675974},
#  {'City': 'kununurra',
#   'Lat': -15.7667,
#   'Lng': 128.7333,
#   'Max Temp': 32.99,
#   'Humidity': 49,
#   'Cloudiness': 20,
#   'Wind Speed': 5.14,
#   'Country': 'AU',
#   'Date': 1725675974},
#  {'City': 'udachny',
#   'Lat': 66.4167,
#   'Lng': 112.4,
#   'Max Temp': 5.42,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 2.98,
#   'Country': 'RU',
#   'Date': 1725675974},
#  {'City': 'ilulissat',
#   'Lat': 69.2167,
#   'Lng': -51.1,
#   'Max Temp': 4.01,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 4.63,
#   'Country': 'GL',
#   'Date': 1725675969},
#  {'City': 'wagar',
#   'Lat': 16.1525,
#   'Lng': 36.2032,
#   'Max Temp': 28.18,
#   'Humidity': 67,
#   'Cloudiness': 20,
#   'Wind Speed': 3.53,
#   'Country': 'SD',
#   'Date': 1725675974},
#  {'City': 'colonia',
#   'Lat': 50.9333,
#   'Lng': 6.95,
#   'Max Temp': 16.06,
#   'Humidity': 88,
#   'Cloudiness': 0,
#   'Wind Speed': 0.51,
#   'Country': 'DE',
#   'Date': 1725675974},
#  {'City': 'contai',
#   'Lat': 21.7786,
#   'Lng': 87.7536,
#   'Max Temp': 29.11,
#   'Humidity': 80,
#   'Cloudiness': 72,
#   'Wind Speed': 4.23,
#   'Country': 'IN',
#   'Date': 1725675974},
#  {'City': 'itoman',
#   'Lat': 26.1247,
#   'Lng': 127.6694,
#   'Max Temp': 32.21,
#   'Humidity': 74,
#   'Cloudiness': 20,
#   'Wind Speed': 2.06,
#   'Country': 'JP',
#   'Date': 1725675975},
#  {'City': 'turbat',
#   'Lat': 26.0023,
#   'Lng': 63.044,
#   'Max Temp': 26.71,
#   'Humidity': 79,
#   'Cloudiness': 4,
#   'Wind Speed': 1.57,
#   'Country': 'PK',
#   'Date': 1725675975},
#  {'City': 'oban',
#   'Lat': 56.4127,
#   'Lng': -5.4706,
#   'Max Temp': 14.59,
#   'Humidity': 81,
#   'Cloudiness': 51,
#   'Wind Speed': 2.76,
#   'Country': 'GB',
#   'Date': 1725675975},
#  {'City': 'muscat',
#   'Lat': 23.6139,
#   'Lng': 58.5922,
#   'Max Temp': 28.5,
#   'Humidity': 71,
#   'Cloudiness': 0,
#   'Wind Speed': 0.86,
#   'Country': 'OM',
#   'Date': 1725675975},
#  {'City': 'es castell',
#   'Lat': 39.8795,
#   'Lng': 4.2854,
#   'Max Temp': 25.38,
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind Speed': 3.6,
#   'Country': 'ES',
#   'Date': 1725675975},
#  {'City': 'stanley',
#   'Lat': 54.868,
#   'Lng': -1.6985,
#   'Max Temp': 15.16,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 3.09,
#   'Country': 'GB',
#   'Date': 1725675688},
#  {'City': 'port elizabeth',
#   'Lat': -33.918,
#   'Lng': 25.5701,
#   'Max Temp': 11.29,
#   'Humidity': 97,
#   'Cloudiness': 20,
#   'Wind Speed': 3.6,
#   'Country': 'ZA',
#   'Date': 1725675975},
#  {'City': 'hirara',
#   'Lat': 24.8,
#   'Lng': 125.2833,
#   'Max Temp': 31.15,
#   'Humidity': 79,
#   'Cloudiness': 40,
#   'Wind Speed': 3.09,
#   'Country': 'JP',
#   'Date': 1725675976},
#  {'City': 'aasiaat',
#   'Lat': 68.7098,
#   'Lng': -52.8699,
#   'Max Temp': 2.19,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 7.43,
#   'Country': 'GL',
#   'Date': 1725675976},
#  {'City': 'pelabuhanratu',
#   'Lat': -6.9875,
#   'Lng': 106.5514,
#   'Max Temp': 29.47,
#   'Humidity': 62,
#   'Cloudiness': 5,
#   'Wind Speed': 1.79,
#   'Country': 'ID',
#   'Date': 1725675976},
#  {'City': 'montanha',
#   'Lat': -18.1269,
#   'Lng': -40.3633,
#   'Max Temp': 19.65,
#   'Humidity': 93,
#   'Cloudiness': 0,
#   'Wind Speed': 2.6,
#   'Country': 'BR',
#   'Date': 1725675976},
#  {'City': 'caleta olivia',
#   'Lat': -46.4393,
#   'Lng': -67.5281,
#   'Max Temp': 9.9,
#   'Humidity': 51,
#   'Cloudiness': 46,
#   'Wind Speed': 14.35,
#   'Country': 'AR',
#   'Date': 1725675976},
#  {'City': 'grand-lahou',
#   'Lat': 5.1367,
#   'Lng': -5.0242,
#   'Max Temp': 22.45,
#   'Humidity': 94,
#   'Cloudiness': 14,
#   'Wind Speed': 3.21,
#   'Country': 'CI',
#   'Date': 1725675976},
#  {'City': 'kimberley',
#   'Lat': -28.7323,
#   'Lng': 24.7623,
#   'Max Temp': 8.83,
#   'Humidity': 43,
#   'Cloudiness': 0,
#   'Wind Speed': 1.03,
#   'Country': 'ZA',
#   'Date': 1725675973},
#  {'City': 'pisco',
#   'Lat': -13.7,
#   'Lng': -76.2167,
#   'Max Temp': 17.03,
#   'Humidity': 77,
#   'Cloudiness': 0,
#   'Wind Speed': 3.09,
#   'Country': 'PE',
#   'Date': 1725675976},
#  {'City': 'kamina',
#   'Lat': -8.7386,
#   'Lng': 24.9906,
#   'Max Temp': 18.76,
#   'Humidity': 40,
#   'Cloudiness': 3,
#   'Wind Speed': 0.81,
#   'Country': 'CD',
#   'Date': 1725675976},
#  {'City': 'prince edward',
#   'Lat': 44.0001,
#   'Lng': -77.2495,
#   'Max Temp': 19.45,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 2.9,
#   'Country': 'CA',
#   'Date': 1725675976},
#  {'City': 'khandyga',
#   'Lat': 62.6667,
#   'Lng': 135.6,
#   'Max Temp': 5.45,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 2.71,
#   'Country': 'RU',
#   'Date': 1725675976},
#  {'City': 'yanam',
#   'Lat': 16.7333,
#   'Lng': 82.2167,
#   'Max Temp': 26.74,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 3.36,
#   'Country': 'IN',
#   'Date': 1725675977},
#  {'City': 'laredo',
#   'Lat': 27.5064,
#   'Lng': -99.5075,
#   'Max Temp': 30.16,
#   'Humidity': 54,
#   'Cloudiness': 0,
#   'Wind Speed': 3.6,
#   'Country': 'US',
#   'Date': 1725675977},
#  {'City': 'acapulco de juarez',
#   'Lat': 16.8634,
#   'Lng': -99.8901,
#   'Max Temp': 29.9,
#   'Humidity': 79,
#   'Cloudiness': 75,
#   'Wind Speed': 3.6,
#   'Country': 'MX',
#   'Date': 1725675977},
#  {'City': 'sandakan',
#   'Lat': 5.8402,
#   'Lng': 118.1179,
#   'Max Temp': 31.82,
#   'Humidity': 70,
#   'Cloudiness': 20,
#   'Wind Speed': 3.6,
#   'Country': 'MY',
#   'Date': 1725675977},
#  {'City': 'lebu',
#   'Lat': -37.6167,
#   'Lng': -73.65,
#   'Max Temp': 9.45,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 1.61,
#   'Country': 'CL',
#   'Date': 1725675977},
#  {'City': 'tiksi',
#   'Lat': 71.6872,
#   'Lng': 128.8694,
#   'Max Temp': 5.31,
#   'Humidity': 54,
#   'Cloudiness': 25,
#   'Wind Speed': 3.69,
#   'Country': 'RU',
#   'Date': 1725675977},
#  {'City': 'constantia',
#   'Lat': 44.1833,
#   'Lng': 28.65,
#   'Max Temp': 19.38,
#   'Humidity': 79,
#   'Cloudiness': 0,
#   'Wind Speed': 8.13,
#   'Country': 'RO',
#   'Date': 1725675845},
#  {'City': 'ola',
#   'Lat': 59.5833,
#   'Lng': 151.2833,
#   'Max Temp': 9.84,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 3.72,
#   'Country': 'RU',
#   'Date': 1725675977},
#  {'City': 'duba',
#   'Lat': 27.3513,
#   'Lng': 35.6901,
#   'Max Temp': 28.94,
#   'Humidity': 59,
#   'Cloudiness': 0,
#   'Wind Speed': 2.13,
#   'Country': 'SA',
#   'Date': 1725675977},
#  {'City': 'san antonio de pale',
#   'Lat': -1.4014,
#   'Lng': 5.6325,
#   'Max Temp': 24.37,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 5.47,
#   'Country': 'GQ',
#   'Date': 1725675977},
#  {'City': 'christchurch',
#   'Lat': -43.5333,
#   'Lng': 172.6333,
#   'Max Temp': 24.12,
#   'Humidity': 33,
#   'Cloudiness': 49,
#   'Wind Speed': 8.23,
#   'Country': 'NZ',
#   'Date': 1725675948},
#  {'City': 'francistown',
#   'Lat': -21.17,
#   'Lng': 27.5079,
#   'Max Temp': 15.29,
#   'Humidity': 32,
#   'Cloudiness': 0,
#   'Wind Speed': 3.62,
#   'Country': 'BW',
#   'Date': 1725675977},
#  {'City': 'gemena',
#   'Lat': 3.25,
#   'Lng': 19.7667,
#   'Max Temp': 20.68,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 0.39,
#   'Country': 'CD',
#   'Date': 1725675978},
#  {'City': 'san cristobal',
#   'Lat': 7.7669,
#   'Lng': -72.225,
#   'Max Temp': 25.74,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 1.41,
#   'Country': 'VE',
#   'Date': 1725675978},
#  {'City': 'kenai',
#   'Lat': 60.5544,
#   'Lng': -151.2583,
#   'Max Temp': 13.41,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 3.6,
#   'Country': 'US',
#   'Date': 1725675978},
#  {'City': 'west valley',
#   'Lat': 46.5921,
#   'Lng': -120.6051,
#   'Max Temp': 32.47,
#   'Humidity': 34,
#   'Cloudiness': 0,
#   'Wind Speed': 3.09,
#   'Country': 'US',
#   'Date': 1725675978},
#  {'City': 'petropavlovsk-kamchatsky',
#   'Lat': 53.0452,
#   'Lng': 158.6483,
#   'Max Temp': 19.33,
#   'Humidity': 32,
#   'Cloudiness': 75,
#   'Wind Speed': 1,
#   'Country': 'RU',
#   'Date': 1725675978},
#  {'City': 'katsuura',
#   'Lat': 35.1333,
#   'Lng': 140.3,
#   'Max Temp': 28.51,
#   'Humidity': 77,
#   'Cloudiness': 60,
#   'Wind Speed': 5.4,
#   'Country': 'JP',
#   'Date': 1725675978},
#  {'City': 'petropavlovka',
#   'Lat': 50.6114,
#   'Lng': 105.3196,
#   'Max Temp': 16.65,
#   'Humidity': 55,
#   'Cloudiness': 98,
#   'Wind Speed': 0.55,
#   'Country': 'RU',
#   'Date': 1725675978},
#  {'City': 'taunggyi',
#   'Lat': 20.7833,
#   'Lng': 97.0333,
#   'Max Temp': 22.55,
#   'Humidity': 86,
#   'Cloudiness': 37,
#   'Wind Speed': 0.64,
#   'Country': 'MM',
#   'Date': 1725675978},
#  {'City': 'al ghayzah',
#   'Lat': 16.2079,
#   'Lng': 52.176,
#   'Max Temp': 25.96,
#   'Humidity': 89,
#   'Cloudiness': 53,
#   'Wind Speed': 2.72,
#   'Country': 'YE',
#   'Date': 1725675768},
#  {'City': "la'ie",
#   'Lat': 21.6477,
#   'Lng': -157.9253,
#   'Max Temp': 30.98,
#   'Humidity': 73,
#   'Cloudiness': 17,
#   'Wind Speed': 2.24,
#   'Country': 'US',
#   'Date': 1725675978},
#  {'City': 'khobar',
#   'Lat': 26.2794,
#   'Lng': 50.2083,
#   'Max Temp': 30.08,
#   'Humidity': 30,
#   'Cloudiness': 0,
#   'Wind Speed': 1.54,
#   'Country': 'SA',
#   'Date': 1725675978},
#  {'City': 'nemuro',
#   'Lat': 43.3236,
#   'Lng': 145.575,
#   'Max Temp': 18.59,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 1.1,
#   'Country': 'JP',
#   'Date': 1725675979},
#  {'City': 'howard springs',
#   'Lat': -12.497,
#   'Lng': 131.047,
#   'Max Temp': 33.32,
#   'Humidity': 50,
#   'Cloudiness': 26,
#   'Wind Speed': 4.37,
#   'Country': 'AU',
#   'Date': 1725675979},
#  {'City': 'griffith',
#   'Lat': 41.5284,
#   'Lng': -87.4237,
#   'Max Temp': 17.92,
#   'Humidity': 62,
#   'Cloudiness': 100,
#   'Wind Speed': 7.72,
#   'Country': 'US',
#   'Date': 1725675979},
#  {'City': 'goure',
#   'Lat': 13.9835,
#   'Lng': 10.2704,
#   'Max Temp': 26.31,
#   'Humidity': 71,
#   'Cloudiness': 5,
#   'Wind Speed': 2.04,
#   'Country': 'NE',
#   'Date': 1725675979},
#  {'City': 'enewetak',
#   'Lat': 11.3474,
#   'Lng': 162.3373,
#   'Max Temp': 28.85,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 7.8,
#   'Country': 'MH',
#   'Date': 1725675979},
#  {'City': 'sao joao da barra',
#   'Lat': -21.6403,
#   'Lng': -41.0511,
#   'Max Temp': 22.13,
#   'Humidity': 92,
#   'Cloudiness': 43,
#   'Wind Speed': 2.94,
#   'Country': 'BR',
#   'Date': 1725675979},
#  {'City': 'marat',
#   'Lat': 25.0701,
#   'Lng': 45.4615,
#   'Max Temp': 29.29,
#   'Humidity': 18,
#   'Cloudiness': 12,
#   'Wind Speed': 2.62,
#   'Country': 'SA',
#   'Date': 1725675979},
#  {'City': 'walvis bay',
#   'Lat': -22.9575,
#   'Lng': 14.5053,
#   'Max Temp': 9.53,
#   'Humidity': 100,
#   'Cloudiness': 0,
#   'Wind Speed': 5.14,
#   'Country': 'NA',
#   'Date': 1725675979},
#  {'City': 'stornoway',
#   'Lat': 58.2093,
#   'Lng': -6.3865,
#   'Max Temp': 12.98,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 1.03,
#   'Country': 'GB',
#   'Date': 1725675742},
#  {'City': 'mocorito',
#   'Lat': 25.4833,
#   'Lng': -107.9167,
#   'Max Temp': 29.2,
#   'Humidity': 65,
#   'Cloudiness': 100,
#   'Wind Speed': 0.14,
#   'Country': 'MX',
#   'Date': 1725675979},
#  {'City': 'minbu',
#   'Lat': 20.1833,
#   'Lng': 94.8833,
#   'Max Temp': 26.32,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 2.87,
#   'Country': 'MM',
#   'Date': 1725675980},
#  {'City': 'yerofey pavlovich',
#   'Lat': 53.9667,
#   'Lng': 121.9667,
#   'Max Temp': 13.27,
#   'Humidity': 42,
#   'Cloudiness': 12,
#   'Wind Speed': 0.71,
#   'Country': 'RU',
#   'Date': 1725675980},
#  {'City': 'khorugh',
#   'Lat': 37.4897,
#   'Lng': 71.553,
#   'Max Temp': 10.43,
#   'Humidity': 38,
#   'Cloudiness': 1,
#   'Wind Speed': 1.53,
#   'Country': 'TJ',
#   'Date': 1725675980},
#  {'City': 'sitka',
#   'Lat': 57.0531,
#   'Lng': -135.33,
#   'Max Temp': 14.94,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 4.63,
#   'Country': 'US',
#   'Date': 1725675980},
#  {'City': 'nova sintra',
#   'Lat': 14.8667,
#   'Lng': -24.7167,
#   'Max Temp': 26.39,
#   'Humidity': 82,
#   'Cloudiness': 75,
#   'Wind Speed': 2.68,
#   'Country': 'CV',
#   'Date': 1725675980},
#  {'City': 'copala',
#   'Lat': 16.65,
#   'Lng': -98.9833,
#   'Max Temp': 27.55,
#   'Humidity': 84,
#   'Cloudiness': 92,
#   'Wind Speed': 2.99,
#   'Country': 'MX',
#   'Date': 1725675980},
#  {'City': 'sabang',
#   'Lat': 5.8933,
#   'Lng': 95.3214,
#   'Max Temp': 26.84,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 12.25,
#   'Country': 'ID',
#   'Date': 1725675980},
#  {'City': 'antofagasta',
#   'Lat': -23.65,
#   'Lng': -70.4,
#   'Max Temp': 15.6,
#   'Humidity': 89,
#   'Cloudiness': 14,
#   'Wind Speed': 2.14,
# ...
#  {'City': 'villa la angostura',
#   'Lat': -40.7617,
#   'Lng': -71.6463,
#   'Max Temp': 1.89,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 3.5,
#   'Country': 'AR',
#   'Date': 1725676004},
#  {'City': 'madalena',
#   'Lat': 41.2162,
#   'Lng': -8.3345,
#   'Max Temp': 15.32,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 2.64,
#   'Country': 'PT',
#   'Date': 1725676004},
#  {'City': 'gusev',
#   'Lat': 54.5922,
#   'Lng': 22.1997,
#   'Max Temp': 15.98,
#   'Humidity': 51,
#   'Cloudiness': 8,
#   'Wind Speed': 3.78,
#   'Country': 'RU',
#   'Date': 1725676004},
#  {'City': 'morinville',
#   'Lat': 53.8001,
#   'Lng': -113.652,
#   'Max Temp': 26.4,
#   'Humidity': 57,
#   'Cloudiness': 100,
#   'Wind Speed': 2.21,
#   'Country': 'CA',
#   'Date': 1725676004},
#  {'City': 'turabah',
#   'Lat': 21.2141,
#   'Lng': 41.6331,
#   'Max Temp': 26.77,
#   'Humidity': 32,
#   'Cloudiness': 7,
#   'Wind Speed': 2.23,
#   'Country': 'SA',
#   'Date': 1725676004},
#  {'City': 'ponta delgada',
#   'Lat': 37.7333,
#   'Lng': -25.6667,
#   'Max Temp': 21.4,
#   'Humidity': 56,
#   'Cloudiness': 75,
#   'Wind Speed': 2.57,
#   'Country': 'PT',
#   'Date': 1725676004},
#  {'City': 'paita',
#   'Lat': -5.0892,
#   'Lng': -81.1144,
#   'Max Temp': 16.88,
#   'Humidity': 85,
#   'Cloudiness': 57,
#   'Wind Speed': 6.12,
#   'Country': 'PE',
#   'Date': 1725676004},
#  {'City': 'guelendeng',
#   'Lat': 10.9176,
#   'Lng': 15.5501,
#   'Max Temp': 22.47,
#   'Humidity': 90,
#   'Cloudiness': 92,
#   'Wind Speed': 1.42,
#   'Country': 'TD',
#   'Date': 1725676004},
#  {'City': 'deir ez-zor',
#   'Lat': 35.3359,
#   'Lng': 40.1408,
#   'Max Temp': 28.16,
#   'Humidity': 58,
#   'Cloudiness': 0,
#   'Wind Speed': 4.86,
#   'Country': 'SY',
#   'Date': 1725676004},
#  {'City': 'san matias',
#   'Lat': -16.3667,
#   'Lng': -58.4,
#   'Max Temp': 26.93,
#   'Humidity': 25,
#   'Cloudiness': 0,
#   'Wind Speed': 2.16,
#   'Country': 'BO',
#   'Date': 1725676004},
#  {'City': 'yaren',
#   'Lat': -0.5472,
#   'Lng': 166.916,
#   'Max Temp': 28.14,
#   'Humidity': 71,
#   'Cloudiness': 15,
#   'Wind Speed': 4.83,
#   'Country': 'NR',
#   'Date': 1725676004},
#  {'City': 'airdrie',
#   'Lat': 55.866,
#   'Lng': -3.9803,
#   'Max Temp': 15.38,
#   'Humidity': 93,
#   'Cloudiness': 69,
#   'Wind Speed': 3.28,
#   'Country': 'GB',
#   'Date': 1725675839},
#  {'City': 'salinopolis',
#   'Lat': -0.6136,
#   'Lng': -47.3561,
#   'Max Temp': 26.67,
#   'Humidity': 79,
#   'Cloudiness': 38,
#   'Wind Speed': 6.01,
#   'Country': 'BR',
#   'Date': 1725676005},
#  {'City': 'ribeira brava',
#   'Lat': 32.65,
#   'Lng': -17.0667,
#   'Max Temp': 22.62,
#   'Humidity': 73,
#   'Cloudiness': 34,
#   'Wind Speed': 1.71,
#   'Country': 'PT',
#   'Date': 1725676005},
#  {'City': 'san pedro pochutla',
#   'Lat': 15.7333,
#   'Lng': -96.4667,
#   'Max Temp': 28.84,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 1.8,
#   'Country': 'MX',
#   'Date': 1725676005},
#  {'City': 'kijang',
#   'Lat': 35.2442,
#   'Lng': 129.2139,
#   'Max Temp': 29.85,
#   'Humidity': 77,
#   'Cloudiness': 87,
#   'Wind Speed': 2.7,
#   'Country': 'KR',
#   'Date': 1725676005},
#  {'City': 'priozersk',
#   'Lat': 61.0393,
#   'Lng': 30.1291,
#   'Max Temp': 12.83,
#   'Humidity': 100,
#   'Cloudiness': 0,
#   'Wind Speed': 2.53,
#   'Country': 'RU',
#   'Date': 1725676005},
#  {'City': 'agapovka',
#   'Lat': 53.2973,
#   'Lng': 59.1348,
#   'Max Temp': 11.56,
#   'Humidity': 82,
#   'Cloudiness': 99,
#   'Wind Speed': 3.52,
#   'Country': 'RU',
#   'Date': 1725676005},
#  {'City': 'el matama',
#   'Lat': 16.7095,
#   'Lng': 33.3565,
#   'Max Temp': 30.86,
#   'Humidity': 53,
#   'Cloudiness': 17,
#   'Wind Speed': 4.43,
#   'Country': 'SD',
#   'Date': 1725676005},
#  {'City': 'stephenville',
#   'Lat': 32.2207,
#   'Lng': -98.2023,
#   'Max Temp': 24.07,
#   'Humidity': 69,
#   'Cloudiness': 0,
#   'Wind Speed': 1.54,
#   'Country': 'US',
#   'Date': 1725675816},
#  {'City': 'kavieng',
#   'Lat': -2.5744,
#   'Lng': 150.7967,
#   'Max Temp': 26.25,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 4.55,
#   'Country': 'PG',
#   'Date': 1725676005},
#  {'City': 'north battleford',
#   'Lat': 52.7834,
#   'Lng': -108.2847,
#   'Max Temp': 20.05,
#   'Humidity': 45,
#   'Cloudiness': 0,
#   'Wind Speed': 5.66,
#   'Country': 'CA',
#   'Date': 1725676005},
#  {'City': 'manadhoo',
#   'Lat': 5.7667,
#   'Lng': 73.3833,
#   'Max Temp': 28.01,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 5.63,
#   'Country': 'MV',
#   'Date': 1725676006},
#  {'City': 'inverloch',
#   'Lat': -38.6333,
#   'Lng': 145.7167,
#   'Max Temp': 13.71,
#   'Humidity': 62,
#   'Cloudiness': 0,
#   'Wind Speed': 7.19,
#   'Country': 'AU',
#   'Date': 1725676006},
#  {'City': 'hadibu',
#   'Lat': 12.65,
#   'Lng': 54.0333,
#   'Max Temp': 25.39,
#   'Humidity': 83,
#   'Cloudiness': 33,
#   'Wind Speed': 7.44,
#   'Country': 'YE',
#   'Date': 1725676006},
#  {'City': 'san andres',
#   'Lat': 12.5847,
#   'Lng': -81.7006,
#   'Max Temp': 28.01,
#   'Humidity': 94,
#   'Cloudiness': 20,
#   'Wind Speed': 0,
#   'Country': 'CO',
#   'Date': 1725675780},
#  {'City': 'kanker',
#   'Lat': 20.2719,
#   'Lng': 81.4931,
#   'Max Temp': 25.19,
#   'Humidity': 88,
#   'Cloudiness': 73,
#   'Wind Speed': 0.54,
#   'Country': 'IN',
#   'Date': 1725676006},
#  {'City': 'broken hill',
#   'Lat': -31.95,
#   'Lng': 141.4333,
#   'Max Temp': 18.06,
#   'Humidity': 34,
#   'Cloudiness': 0,
#   'Wind Speed': 3.77,
#   'Country': 'AU',
#   'Date': 1725675854},
#  {'City': 'kemijarvi',
#   'Lat': 66.7131,
#   'Lng': 27.4306,
#   'Max Temp': 14.16,
#   'Humidity': 91,
#   'Cloudiness': 15,
#   'Wind Speed': 4.26,
#   'Country': 'FI',
#   'Date': 1725676006},
#  {'City': 'stassfurt',
#   'Lat': 51.8396,
#   'Lng': 11.58,
#   'Max Temp': 17.16,
#   'Humidity': 50,
#   'Cloudiness': 40,
#   'Wind Speed': 2.19,
#   'Country': 'DE',
#   'Date': 1725676006},
#  {'City': 'sofifi',
#   'Lat': 0.7349,
#   'Lng': 127.576,
#   'Max Temp': 28.99,
#   'Humidity': 71,
#   'Cloudiness': 70,
#   'Wind Speed': 0.7,
#   'Country': 'ID',
#   'Date': 1725676006},
#  {'City': 'shimoda',
#   'Lat': 34.6667,
#   'Lng': 138.95,
#   'Max Temp': 29.8,
#   'Humidity': 66,
#   'Cloudiness': 75,
#   'Wind Speed': 3.91,
#   'Country': 'JP',
#   'Date': 1725676006},
#  {'City': 'fort mcmurray',
#   'Lat': 56.7268,
#   'Lng': -111.381,
#   'Max Temp': 18.73,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 2.06,
#   'Country': 'CA',
#   'Date': 1725675768},
#  {'City': 'nagato',
#   'Lat': 34.3833,
#   'Lng': 131.2,
#   'Max Temp': 29.23,
#   'Humidity': 64,
#   'Cloudiness': 82,
#   'Wind Speed': 2.08,
#   'Country': 'JP',
#   'Date': 1725676007},
#  {'City': 'kundla',
#   'Lat': 21.3333,
#   'Lng': 71.3,
#   'Max Temp': 24.66,
#   'Humidity': 92,
#   'Cloudiness': 98,
#   'Wind Speed': 2.41,
#   'Country': 'IN',
#   'Date': 1725676007},
#  {'City': 'bandar-e lengeh',
#   'Lat': 26.5579,
#   'Lng': 54.8807,
#   'Max Temp': 31.06,
#   'Humidity': 89,
#   'Cloudiness': 0,
#   'Wind Speed': 0,
#   'Country': 'IR',
#   'Date': 1725676007},
#  {'City': 'naranjal',
#   'Lat': -2.6667,
#   'Lng': -79.6167,
#   'Max Temp': 21.94,
#   'Humidity': 82,
#   'Cloudiness': 57,
#   'Wind Speed': 1.26,
#   'Country': 'EC',
#   'Date': 1725676007},
#  {'City': 'bonny',
#   'Lat': 4.4522,
#   'Lng': 7.1681,
#   'Max Temp': 24.6,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 2.72,
#   'Country': 'NG',
#   'Date': 1725676007},
#  {'City': 'portland',
#   'Lat': 45.5234,
#   'Lng': -122.6762,
#   'Max Temp': 31.99,
#   'Humidity': 46,
#   'Cloudiness': 0,
#   'Wind Speed': 2.57,
#   'Country': 'US',
#   'Date': 1725675719},
#  {'City': 'fougamou',
#   'Lat': -1.2154,
#   'Lng': 10.5838,
#   'Max Temp': 23.07,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 0.77,
#   'Country': 'GA',
#   'Date': 1725676008},
#  {'City': 'bamboo flat',
#   'Lat': 11.7,
#   'Lng': 92.7167,
#   'Max Temp': 29.05,
#   'Humidity': 84,
#   'Cloudiness': 75,
#   'Wind Speed': 5.66,
#   'Country': 'IN',
#   'Date': 1725676008},
#  {'City': 'mumbwa',
#   'Lat': -14.9783,
#   'Lng': 27.0619,
#   'Max Temp': 15.91,
#   'Humidity': 40,
#   'Cloudiness': 95,
#   'Wind Speed': 2.29,
#   'Country': 'ZM',
#   'Date': 1725676008},
#  {'City': 'uyskoye',
#   'Lat': 54.3775,
#   'Lng': 60.0047,
#   'Max Temp': 12.12,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 5.55,
#   'Country': 'RU',
#   'Date': 1725676008},
#  {'City': 'tazacorte',
#   'Lat': 28.629,
#   'Lng': -17.9293,
#   'Max Temp': 21.54,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 3.6,
#   'Country': 'ES',
#   'Date': 1725676008},
#  {'City': 'altai',
#   'Lat': 46.3722,
#   'Lng': 96.2583,
#   'Max Temp': 16.63,
#   'Humidity': 21,
#   'Cloudiness': 1,
#   'Wind Speed': 5.71,
#   'Country': 'MN',
#   'Date': 1725676008},
#  {'City': 'camacupa',
#   'Lat': -12.0167,
#   'Lng': 17.4833,
#   'Max Temp': 16.76,
#   'Humidity': 29,
#   'Cloudiness': 100,
#   'Wind Speed': 1.29,
#   'Country': 'AO',
#   'Date': 1725676008},
#  {'City': 'malvan',
#   'Lat': 16.0667,
#   'Lng': 73.4667,
#   'Max Temp': 26.55,
#   'Humidity': 81,
#   'Cloudiness': 99,
#   'Wind Speed': 0.32,
#   'Country': 'IN',
#   'Date': 1725676008},
#  {'City': 'labytnangi',
#   'Lat': 66.6572,
#   'Lng': 66.4183,
#   'Max Temp': 8.42,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 5.79,
#   'Country': 'RU',
#   'Date': 1725676008},
#  {'City': 'onguday',
#   'Lat': 50.75,
#   'Lng': 86.15,
#   'Max Temp': 8.98,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 0.29,
#   'Country': 'RU',
#   'Date': 1725676008},
#  {'City': 'kolwezi',
#   'Lat': -10.7148,
#   'Lng': 25.4667,
#   'Max Temp': 16.64,
#   'Humidity': 39,
#   'Cloudiness': 32,
#   'Wind Speed': 2.48,
#   'Country': 'CD',
#   'Date': 1725676008},
#  {'City': 'paphos',
#   'Lat': 34.7667,
#   'Lng': 32.4167,
#   'Max Temp': 24.88,
#   'Humidity': 57,
#   'Cloudiness': 0,
#   'Wind Speed': 1.54,
#   'Country': 'CY',
#   'Date': 1725676009},
#  {'City': 'piacabucu',
#   'Lat': -10.4056,
#   'Lng': -36.4344,
#   'Max Temp': 23.08,
#   'Humidity': 85,
#   'Cloudiness': 26,
#   'Wind Speed': 4.06,
#   'Country': 'BR',
#   'Date': 1725676009},
#  {'City': 'kani keli',
#   'Lat': -12.9536,
#   'Lng': 45.1033,
#   'Max Temp': 24.59,
#   'Humidity': 72,
#   'Cloudiness': 29,
#   'Wind Speed': 5.05,
#   'Country': 'YT',
#   'Date': 1725676009},
#  {'City': 'fukuecho',
#   'Lat': 32.6881,
#   'Lng': 128.8419,
#   'Max Temp': 30.2,
#   'Humidity': 66,
#   'Cloudiness': 20,
#   'Wind Speed': 2.57,
#   'Country': 'JP',
#   'Date': 1725676009},
#  {'City': 'ardabil',
#   'Lat': 38.2498,
#   'Lng': 48.2933,
#   'Max Temp': 4.75,
#   'Humidity': 100,
#   'Cloudiness': 0,
#   'Wind Speed': 0,
#   'Country': 'IR',
#   'Date': 1725676009},
#  {'City': 'cidreira',
#   'Lat': -30.1811,
#   'Lng': -50.2056,
#   'Max Temp': 15.38,
#   'Humidity': 93,
#   'Cloudiness': 23,
#   'Wind Speed': 7.45,
#   'Country': 'BR',
#   'Date': 1725676009},
#  {'City': 'aioun',
#   'Lat': 16.6614,
#   'Lng': -9.6149,
#   'Max Temp': 26.57,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 6.14,
#   'Country': 'MR',
#   'Date': 1725676009},
#  {'City': 'gulf shores',
#   'Lat': 30.246,
#   'Lng': -87.7008,
#   'Max Temp': 25.19,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Date': 1725675761},
#  {'City': 'guskhara',
#   'Lat': 23.5,
#   'Lng': 87.75,
#   'Max Temp': 30.46,
#   'Humidity': 69,
#   'Cloudiness': 23,
#   'Wind Speed': 2.16,
#   'Country': 'IN',
#   'Date': 1725676009},
#  {'City': 'kouroussa',
#   'Lat': 10.65,
#   'Lng': -9.8833,
#   'Max Temp': 22.19,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 3.54,
#   'Country': 'GN',
#   'Date': 1725676009},
#  {'City': 'olyokminsk',
#   'Lat': 60.3736,
#   'Lng': 120.4264,
#   'Max Temp': 4.92,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 3.73,
#   'Country': 'RU',
#   'Date': 1725676010},
#  {'City': 'koungou',
#   'Lat': -12.7336,
#   'Lng': 45.2042,
#   'Max Temp': 24.84,
#   'Humidity': 88,
#   'Cloudiness': 20,
#   'Wind Speed': 6.17,
#   'Country': 'YT',
#   'Date': 1725676010},
#  {'City': 'al bawiti',
#   'Lat': 28.3492,
#   'Lng': 28.8659,
#   'Max Temp': 25.04,
#   'Humidity': 56,
#   'Cloudiness': 0,
#   'Wind Speed': 3.03,
#   'Country': 'EG',
#   'Date': 1725676010},
#  {'City': 'dalandzadgad',
#   'Lat': 43.5708,
#   'Lng': 104.425,
#   'Max Temp': 21.01,
#   'Humidity': 26,
#   'Cloudiness': 0,
#   'Wind Speed': 4.12,
#   'Country': 'MN',
#   'Date': 1725676010},
#  {'City': 'aksu',
#   'Lat': 41.1231,
#   'Lng': 80.2644,
#   'Max Temp': 22.95,
#   'Humidity': 30,
#   'Cloudiness': 3,
#   'Wind Speed': 0.47,
#   'Country': 'CN',
#   'Date': 1725676010},
#  {'City': 'vernon',
#   'Lat': 50.2581,
#   'Lng': -119.2691,
#   'Max Temp': 28.29,
#   'Humidity': 34,
#   'Cloudiness': 0,
#   'Wind Speed': 1.03,
#   'Country': 'CA',
#   'Date': 1725676010},
#  {'City': 'roma',
#   'Lat': 43.2128,
#   'Lng': -75.4557,
#   'Max Temp': 18.39,
#   'Humidity': 84,
#   'Cloudiness': 0,
#   'Wind Speed': 2.57,
#   'Country': 'US',
#   'Date': 1725676010},
#  {'City': 'aviles',
#   'Lat': 43.5547,
#   'Lng': -5.9248,
#   'Max Temp': 13.84,
#   'Humidity': 83,
#   'Cloudiness': 0,
#   'Wind Speed': 5.66,
#   'Country': 'ES',
#   'Date': 1725676010},
#  {'City': 'dolzhanskaya',
#   'Lat': 46.6311,
#   'Lng': 37.8039,
#   'Max Temp': 18.74,
#   'Humidity': 46,
#   'Cloudiness': 1,
#   'Wind Speed': 10.49,
#   'Country': 'RU',
#   'Date': 1725676010},
#  {'City': 'niafunke',
#   'Lat': 15.9322,
#   'Lng': -3.9906,
#   'Max Temp': 26.68,
#   'Humidity': 78,
#   'Cloudiness': 99,
#   'Wind Speed': 5.05,
#   'Country': 'ML',
#   'Date': 1725676010},
#  {'City': 'vershino-darasunskiy',
#   'Lat': 52.35,
#   'Lng': 115.5167,
#   'Max Temp': 11.79,
#   'Humidity': 52,
#   'Cloudiness': 100,
#   'Wind Speed': 2.2,
#   'Country': 'RU',
#   'Date': 1725676011},
#  {'City': 'kapuskasing',
#   'Lat': 49.4169,
#   'Lng': -82.4331,
#   'Max Temp': 7,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 5.66,
#   'Country': 'CA',
#   'Date': 1725676011},
#  {'City': 'winslow',
#   'Lat': 35.0242,
#   'Lng': -110.6974,
#   'Max Temp': 30.1,
#   'Humidity': 15,
#   'Cloudiness': 0,
#   'Wind Speed': 1.54,
#   'Country': 'US',
#   'Date': 1725676011},
#  {'City': 'shaowu',
#   'Lat': 27.3409,
#   'Lng': 117.4831,
#   'Max Temp': 30.77,
#   'Humidity': 71,
#   'Cloudiness': 0,
#   'Wind Speed': 1.59,
#   'Country': 'CN',
#   'Date': 1725676011},
#  {'City': 'nagqu',
#   'Lat': 31.5,
#   'Lng': 92,
#   'Max Temp': 8.08,
#   'Humidity': 69,
#   'Cloudiness': 59,
#   'Wind Speed': 2.37,
#   'Country': 'CN',
#   'Date': 1725676011},
#  {'City': 'ordynskoye',
#   'Lat': 54.3656,
#   'Lng': 81.8994,
#   'Max Temp': 9.99,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 3.78,
#   'Country': 'RU',
#   'Date': 1725676011},
#  {'City': 'shalkar',
#   'Lat': 47.8288,
#   'Lng': 59.6258,
#   'Max Temp': 11.56,
#   'Humidity': 50,
#   'Cloudiness': 0,
#   'Wind Speed': 2.57,
#   'Country': 'KZ',
#   'Date': 1725676011},
#  {'City': 'cafayate',
#   'Lat': -26.073,
#   'Lng': -65.9761,
#   'Max Temp': 18.18,
#   'Humidity': 31,
#   'Cloudiness': 0,
#   'Wind Speed': 0.94,
#   'Country': 'AR',
#   'Date': 1725676011},
#  {'City': 'karratha',
#   'Lat': -20.7377,
#   'Lng': 116.8463,
#   'Max Temp': 28.23,
#   'Humidity': 33,
#   'Cloudiness': 0,
#   'Wind Speed': 5.47,
#   'Country': 'AU',
#   'Date': 1725676011},
#  {'City': 'kirensk',
#   'Lat': 57.7853,
#   'Lng': 108.1119,
#   'Max Temp': 10.64,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 1.22,
#   'Country': 'RU',
#   'Date': 1725676011},
#  {'City': 'kanniyakumari',
#   'Lat': 8.0833,
#   'Lng': 77.5667,
#   'Max Temp': 26.83,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 8.51,
#   'Country': 'IN',
#   'Date': 1725676011},
#  {'City': "n'zeto",
#   'Lat': -7.2312,
#   'Lng': 12.8666,
#   'Max Temp': 21.4,
#   'Humidity': 92,
#   'Cloudiness': 28,
#   'Wind Speed': 2.74,
#   'Country': 'AO',
#   'Date': 1725676012},
#  {'City': 'mount gambier',
#   'Lat': -37.8333,
#   'Lng': 140.7667,
#   'Max Temp': 15.26,
#   'Humidity': 56,
#   'Cloudiness': 26,
#   'Wind Speed': 5.87,
#   'Country': 'AU',
#   'Date': 1725676012},
#  {'City': 'tayoltita',
#   'Lat': 24.0833,
#   'Lng': -105.9333,
#   'Max Temp': 24.45,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 3.21,
#   'Country': 'MX',
#   'Date': 1725676012},
#  {'City': 'haiku-pauwela',
#   'Lat': 20.9219,
#   'Lng': -156.3051,
#   'Max Temp': 28.01,
#   'Humidity': 70,
#   'Cloudiness': 40,
#   'Wind Speed': 9.77,
#   'Country': 'US',
#   'Date': 1725676012},
#  {'City': 'muang phon-hong',
#   'Lat': 18.4928,
#   'Lng': 102.4172,
#   'Max Temp': 26.63,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 0.87,
#   'Country': 'LA',
#   'Date': 1725676012},
#  {'City': 'ciudad guadalupe victoria',
#   'Lat': 24.4497,
#   'Lng': -104.1225,
#   'Max Temp': 16.74,
#   'Humidity': 78,
#   'Cloudiness': 61,
#   'Wind Speed': 6.36,
#   'Country': 'MX',
#   'Date': 1725676012},
#  {'City': 'kikwit',
#   'Lat': -5.041,
#   'Lng': 18.8162,
#   'Max Temp': 23.99,
#   'Humidity': 69,
#   'Cloudiness': 8,
#   'Wind Speed': 0.81,
#   'Country': 'CD',
#   'Date': 1725676012}]

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          579
# Lat           579
# Lng           579
# Max Temp      579
# Humidity      579
# Cloudiness    579
# Wind Speed    579
# Country       579
# Date          579
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     puerto natales -51.7236  -72.4875      3.38        96         100
# 1      morehead city  34.7229  -76.7260     24.44        86           0
# 2          adamstown -25.0660 -130.1015     18.33        78         100
# 3  novonikolayevskiy  50.9738   42.3649     10.67        53           0
# 4           hengchun  22.0042  120.7439     27.35        82         100
#
#    Wind Speed Country        Date
# 0        2.68      CL  1725675954
# 1        2.24      US  1725675954
# 2       10.32      PN  1725675954
# 3        1.75      RU  1725675954
# 4        4.52      TW  1725675955

# %%
# # Convert datetime to readable date format
city_data_df['Date']=(pd.to_datetime(city_data_df['Date'],unit='s')).dt.date
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     puerto natales -51.7236  -72.4875      3.38        96         100
# 1      morehead city  34.7229  -76.7260     24.44        86           0
# 2          adamstown -25.0660 -130.1015     18.33        78         100
# 3  novonikolayevskiy  50.9738   42.3649     10.67        53           0
# 4           hengchun  22.0042  120.7439     27.35        82         100
#
#    Wind Speed Country        Date
# 0        2.68      CL  2024-09-07
# 1        2.24      US  2024-09-07
# 2       10.32      PN  2024-09-07
# 3        1.75      RU  2024-09-07
# 4        4.52      TW  2024-09-07

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %% [markdown]
# ### BEGIN HERE To recreate the plots begin running code here after importing Dependecies

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0           puerto natales -51.7236  -72.4875      3.38        96         100
# 1            morehead city  34.7229  -76.7260     24.44        86           0
# 2                adamstown -25.0660 -130.1015     18.33        78         100
# 3        novonikolayevskiy  50.9738   42.3649     10.67        53           0
# 4                 hengchun  22.0042  120.7439     27.35        82         100
#
#          Wind Speed Country        Date
# City_ID
# 0              2.68      CL  2024-09-07
# 1              2.24      US  2024-09-07
# 2             10.32      PN  2024-09-07
# 3              1.75      RU  2024-09-07
# 4              4.52      TW  2024-09-07

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], marker="o")

# Incorporate the other graph properties
plt.title("City Temperature vs Max Temp")
plt.ylabel("Max Temperature (C)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs Humidity")
plt.ylabel("Humidity(%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs Cloudiness")
plt.ylabel("Cloudiness(%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs Wind Speed")
plt.ylabel("Wind Speed (m/s)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df['Lat'] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1            morehead city  34.7229  -76.7260     24.44        86           0
# 3        novonikolayevskiy  50.9738   42.3649     10.67        53           0
# 4                 hengchun  22.0042  120.7439     27.35        82         100
# 6                glace bay  46.1969  -59.9570     17.16        88          75
# 7              trincomalee   8.5711   81.2335     27.99        75          99
#
#          Wind Speed Country        Date
# City_ID
# 1              2.24      US  2024-09-07
# 3              1.75      RU  2024-09-07
# 4              4.52      TW  2024-09-07
# 6              1.34      CA  2024-09-07
# 7              9.91      LK  2024-09-07

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df['Lat'] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        puerto natales -51.7236  -72.4875      3.38        96         100
# 2             adamstown -25.0660 -130.1015     18.33        78         100
# 5             grytviken -54.2811  -36.5092      1.09        91          98
# 9              kirakira -10.4544  161.9205     27.10        66         100
# 10             waitangi -43.9535 -176.5597     12.12        84          86
#
#          Wind Speed Country        Date
# City_ID
# 0              2.68      CL  2024-09-07
# 2             10.32      PN  2024-09-07
# 5              1.15      GS  2024-09-07
# 9              8.07      SB  2024-09-07
# 10             3.58      NZ  2024-09-07

# %%
###  Temperature vs. Latitude Linear Regression Plot

# %% [markdown]
# Linear regression on Northern Hemisphere

# %%
# Create x and y values for Northern Hemishphere
x_values_nh = northern_hemi_df['Lat']
y_values_nh = northern_hemi_df['Max Temp']

# Perform a linear regression on Max Temp vs. Northern Hemisphere latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values_nh, y_values_nh)

# Get regression values
regress_values_nh = x_values_nh * slope + intercept

# Create line equation string
line_eq_nh = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Create Plot
plt.scatter(x_values_nh,y_values_nh)
plt.plot(x_values_nh,regress_values_nh,"r-")

# Label plot and annotate the line equation
plt.title("Northern Latitude vs Max Temp")
plt.xlabel('Northern Hemisphere Latitude')
plt.ylabel('Max Temperature')
plt.annotate(line_eq_nh,(50,30),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.5898159553700391

# %% [markdown]
# Linear regression on Southern Hemisphere

# %%
# Create x and y values for Southern Hemishphere
x_values_sh = southern_hemi_df['Lat']
y_values_sh = southern_hemi_df['Max Temp']

# Perform a linear regression on Max Temp vs. Southern Hemisphere latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values_sh, y_values_sh)

# Get regression values
regress_values = x_values_sh * slope + intercept

# Create line equation string
line_eq_sh = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Create Plot
plt.scatter(x_values_sh,y_values_sh)
plt.plot(x_values_sh,regress_values,"r-")

# Label plot and annotate the line equation
plt.title("Southern Latitude vs Max Temp")
plt.xlabel('Southern Hemisphere Latitude')
plt.ylabel('Max Temperature')
plt.annotate(line_eq_sh,(-40,5),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.5736325154348209

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot
# **Discussion about the linear relationship:**<br/>
#  - In the Northern Hemisphere there is a negative linear relationship with an r-value of 0.58 - meaning that the further from the equator the lower the Max Temps is.
#  - In the Southern Hemisphere the opposite is true - there is a positive linear relationship and an r-value of 0.57 - meaning that the closer to the equator the greater the Max Temp is.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# Create x and y values for Northern Hemishphere
x_values_nh = northern_hemi_df['Lat']
y_values_nh = northern_hemi_df['Humidity']

# Perform a linear regression on Max Temp vs. Northern Hemisphere latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values_nh, y_values_nh)

# Get regression values
regress_values_nh = x_values_nh * slope + intercept

# Create line equation string
line_eq_nh = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Create Plot
plt.scatter(x_values_nh,y_values_nh)
plt.plot(x_values_nh,regress_values_nh,"r-")

# Label plot and annotate the line equation
plt.title("Northern Latitude vs Humidity")
plt.xlabel('Northern Hemisphere Latitude')
plt.ylabel('Humidity')
plt.annotate(line_eq_nh,(50,20),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.0012134349936101985

# %%
# Southern Hemisphere
# Create x and y values for Southern Hemishphere
x_values_sh = southern_hemi_df['Lat']
y_values_sh = southern_hemi_df['Humidity']

# Perform a linear regression on Max Temp vs. Southern Hemisphere latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values_sh, y_values_sh)

# Get regression values
regress_values = x_values_sh * slope + intercept

# Create line equation string
line_eq_sh = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Create Plot
plt.scatter(x_values_sh,y_values_sh)
plt.plot(x_values_sh,regress_values,"r-")

# Label plot and annotate the line equation
plt.title("Southern Latitude vs Humidity")
plt.xlabel('Southern Hemisphere Latitude')
plt.ylabel('Humidity')
plt.annotate(line_eq_sh,(-50,20),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.0036594230832145123

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot
# **Discussion about the linear relationship:**<br/>
#  - In both the Northern and Southern Hemispheres the linear regression line is almost horizontal (although it is negative) and with an r-value bwetween 0.001 and 0.003 - meaning that the relationship between Latitude and Humidity is very weak as there is almost no relationship between Humidity and Latitude.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# Create x and y values for Northern Hemishphere
x_values_nh = northern_hemi_df['Lat']
y_values_nh = northern_hemi_df['Cloudiness']

# Perform a linear regression on Max Temp vs. Northern Hemisphere latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values_nh, y_values_nh)

# Get regression values
regress_values_nh = x_values_nh * slope + intercept

# Create line equation string
line_eq_nh = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Create Plot
plt.scatter(x_values_nh,y_values_nh)
plt.plot(x_values_nh,regress_values_nh,"r-")

# Label plot and annotate the line equation
plt.title("Northern Latitude vs Cloudiness")
plt.xlabel('Northern Hemisphere Latitude')
plt.ylabel('Cloudiness')
plt.annotate(line_eq_nh,(0,0),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 3.887965791456354e-05

# %%
# Southern Hemisphere
# Create x and y values for Southern Hemishphere
x_values_sh = southern_hemi_df['Lat']
y_values_sh = southern_hemi_df['Cloudiness']

# Perform a linear regression on Max Temp vs. Southern Hemisphere latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values_sh, y_values_sh)

# Get regression values
regress_values = x_values_sh * slope + intercept

# Create line equation string
line_eq_sh = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Create Plot
plt.scatter(x_values_sh,y_values_sh)
plt.plot(x_values_sh,regress_values,"r-")

# Label plot and annotate the line equation
plt.title("Southern Latitude vs Cloudiness")
plt.xlabel('Southern Hemisphere Latitude')
plt.ylabel('Cloudiness')
plt.annotate(line_eq_sh,(-40,5),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.0001597472918406383

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot
# **Discussion about the linear relationship:**<br/>
# - Similar to the results from Humidity and Latitude, both the Nothern and Southern Hemispheres the linear regression line and R-values show no relationship between Cloudiness and Latitude.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# Create x and y values for Northern Hemishphere
x_values_nh = northern_hemi_df['Lat']
y_values_nh = northern_hemi_df['Wind Speed']

# Perform a linear regression on Max Temp vs. Northern Hemisphere latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values_nh, y_values_nh)

# Get regression values
regress_values_nh = x_values_nh * slope + intercept

# Create line equation string
line_eq_nh = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Create Plot
plt.scatter(x_values_nh,y_values_nh)
plt.plot(x_values_nh,regress_values_nh,"r-")

# Label plot and annotate the line equation
plt.title("Northern Latitude vs Wind Speed")
plt.xlabel('Northern Hemisphere Latitude')
plt.ylabel('Wind Speed')
plt.annotate(line_eq_nh,(0,0),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.011688628500160142

# %%
# Southern Hemisphere
# Create x and y values for Southern Hemishphere
x_values_sh = southern_hemi_df['Lat']
y_values_sh = southern_hemi_df['Wind Speed']

# Perform a linear regression on Max Temp vs. Southern Hemisphere latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values_sh, y_values_sh)

# Get regression values
regress_values = x_values_sh * slope + intercept

# Create line equation string
line_eq_sh = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Create Plot
plt.scatter(x_values_sh,y_values_sh)
plt.plot(x_values_sh,regress_values,"r-")

# Label plot and annotate the line equation
plt.title("Southern Latitude vs Wind Speed")
plt.xlabel('Southern Hemisphere Latitude')
plt.ylabel('Wind Speed')
plt.annotate(line_eq_sh,(-40,5),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.04019505309827347

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot
# **Discussion about the linear relationship:**<br/>
#  - In both the Northern and Southern Hemispheres the linear regression line is almost horizontal.  The Northern Hemisphere is at a negative slope and the Southern Hemisphere is at a positive slope.  However, with r-values between 0.011 and 0.04 there may be a small correlation between Wind Speed and Latitude - especially in the Southern Hemisphere - but additional information should be gathered before making this correlation.
